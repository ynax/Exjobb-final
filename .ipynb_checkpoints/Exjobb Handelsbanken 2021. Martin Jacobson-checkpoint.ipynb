# %% [markdown]
# ## A good title

# %% [markdown]
# This notebook includes the final results of the master thesis "XXX" by Martin Jacobson, 2021-05.

# %% [markdown]
# The structure is the following:
# 1. Load datasets and visualize them in two dimensions.
# 2. With ELM and KFoldCross validation showcase difference in MCC between them.
# 3. Get Feature importance form Extra Trees or Random Forest.
# 4. For each group of models on a set of datasets, Loop following steps. Grouping of model as;
#     (Multilayer Perceptron, ELM)
#     (ELSVM, RUTSVM, CS-SVM)
#     (Random Forests, Decision Tree, Bagging Decision Trees, Extra Trees)
#     2. Test PCA reduction, increasing one dimension at a time.
#     2. Adding one feature at at time, train top N models for each classifier and get new results.
#     3. With a subset of features train models with sampling. Over-Under... etc..
#     4. Chaninging (train-test)-validation splits
#     5. Showcase training times for models by using one dataset with increasing number of samples.
#     6. Train and optimize. Visualize Recall-Precision plot and MCC, with std.

# %% [markdown]
# Homebuilt functions can be viewed in 'funs.py'

# %%
'Import homebuilt functions'
from funs import *

'Import Classifiers'
from ELM import ELM 

'Import train test splits'
from sklearn.model_selection import train_test_split

'Import plotting'
import seaborn as sns
sns.set(style="whitegrid")

import warnings
warnings.filterwarnings('ignore')

# %%
Datasets = {      
    'Standard':'no_agg_encoded',   # Jan-Feb
    'Aggregated 1':'agg0_encoded', # with frauds
    'Aggregated 2':'agg1_encoded', # with trans last 6,3,1m 
    'Aggregated 3':'agg2_encoded', # Periodic aggregated
    'Aggregated 4':'agg3_encoded', # Reciver, country, and bic specific no.trans, no.frauds..
    'Aggregated 1+2':'agg01_encoded',
    'Aggregated 1+2+4':'agg013_encoded',
    'Aggregated 1+2+3+4':'agg0123_encoded',    
#     'Dal Pozzolo Dataset':'DAL_P',
#     'All trans':'SHB_3_wR_wE',     # All transactions Jan-Mar
    'Standard 2':'OneTypeTrans3_wR_wE', # Jan-Mar
}
folder = "/Users/Martin/Documents/Exjobb_Handelsbanken/Data"

# %% [markdown]
# ## Visualize Datasets

# %%
save_folder = 'Plots/visualize_datasets'
tempDataset = {'Standard':'no_agg_encoded'}

key = 'Standard 2'
for i in [1]:
# for i,key in enumerate(Datasets.keys()):
    df = read_data(Datasets[key],folder)
    mask = df['Class'] == 0
    n = min(100,mask[mask].shape[0]-1)
#     n = min(3000,mask[mask].shape[0]-1)
    
    non_fraud = df[mask].sample(n)
    fraud = df[~mask]
    df = non_fraud.append(fraud).sample(frac=1).reset_index(drop=True)

    X,Y = get_sets(df.copy())
    X,_ = scale_data(X,'Standard')    
    
    tsne_plot(X, Y, 
              save_name="{}/{}.png".format(save_folder,key),
              title='tSNE, Dataset: {}'.format(key),
              save=True, show=True, verbose=False,
              alpha_F=1, alpha_G=0.8,
              marker_F='X', marker_G='o'
              )

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# Correlation plots first.
#
# Difference between my Datasets and Pozzolo's is that his is already gone through a PCA transformation.

# %%
save_folder = 'Plots/Correlation'
key = 'Standard 2'
for i in [1]:
# for i,key in enumerate(Datasets.keys()):
#     df = read_data(Datasets[key],folder)
    f = plt.figure(figsize=(12, 8))
      
    corr = df.corr()
    sns.heatmap(corr, 
                xticklabels=corr.columns.values,
                yticklabels=corr.columns.values,
               vmin=-1,
               vmax=1,
               cmap='viridis',
               center=0,
               cbar_kws={"ticks":[-1,-.5,0,.5,1]},
               )
    plt.title('Dataset: {}'.format(key),fontdict ={'fontsize':20})
    plt.tight_layout()
    plt.savefig('{}/{}.png'.format(save_folder,key))
    plt.show()

# %% [markdown]
# Create a dictionary for each dataset which will store needed information.

# %%
set_dict = {}
for key in Datasets.keys():
    set_dict[key] = {}
    set_dict[key]['filename'] = Datasets[key]

# %% [markdown]
# Feature Importance scores.
# We are training one model one the WHOLE dataset. This is because it is very important to not lose any information for each feature. A subset could over-/under-estimate each feature and would make the decision to remove features less prudent.
#
# We train two identical Random Forest models with different split criterion; 'gini' and 'entropy'. Afterwards, since each criterion yields results within the same range, we average the measures to determine the 'True' importance order. We do not expect to gain to much by averaging. Bad features will rank low for both, but a bad feature might be super bad for one but not as much by the other.

# %%
save_folder = 'Plots/Feature Importance'
# key = 'Standard 2'
# for i in [1]:
for i,key in enumerate(Datasets.keys()):
    print(key)
    df = read_data(Datasets[key],folder)
    Y = df.pop('Class')
    evaluator= ['Extra','Decision','Random']
    evaluator = 'Random'
    
    fig, ax = plt.subplots(2,1,figsize=(10,5),sharex=False,sharey=True)
    plt.tight_layout()
    col_order,importance = evaluate_features(df,Y,
                                             n_estimators=10,
                                             n_jobs=2,
                                             evaluator=evaluator,
                                            criterion='gini')
    col_order2,importance2 = evaluate_features(df,Y,
                                               n_estimators=10,
                                            n_jobs=2,
                                            evaluator=evaluator,
                                            criterion='entropy')
    
    temp = plot_feature_importance(col_order,importance,
                               sort=True,
                               ascending=False,
                               show=False,
                               ax= ax[0],
                            title_fontsize=10,
                            x_fontsize=10,
                            y_fontsize=10,
                            x_tick_size=10,
                            y_tick_size=10,
                               title='Dataset: {}, Evaluator: {}'.format(key,evaluator));    
    temp = plot_feature_importance(col_order2,importance2,
                               sort=True,
                               ascending=False,
                               show=False,
                               ax= ax[1],
                            title_fontsize=10,
                                x_fontsize=20,
                            y_fontsize=10,
                            x_tick_size=10,
                            y_tick_size=10,
                               title='Dataset: {}, Evaluator: {}'.format(key,evaluator));
    title='Dataset: {}, Evaluator: {}'.format(key,evaluator)
    ax[1].set_ylabel('')
    ax[0].set_ylabel('')
    ax[0].set_xlabel('')
    ax[0].title.set_text('Gini Scores')
    ax[1].title.set_text('Entropy Scores')
    fig.text(-0.05, 0.5, 'Importance weights',size=20, va='center', rotation='vertical')
    fig.text(0.3, 1.05, title,size=20)#, va='left')
    
#     fig.savefig('{}/{}.png'.format(save_folder,key+'_gini_entorpy'), bbox_inches = "tight");
#     plt.close()
    
    order_df = pd.DataFrame()
    order_df.loc[:,'index'] = df.columns[col_order]
    order_df.set_index('index',inplace=True,drop=True)

    
    cols1 = df.columns[col_order]
    cols2 = df.columns[col_order2]
    order_df.loc[cols1,'Gini'] = importance
    order_df.loc[cols2,'Entropy'] = importance2
    
    order_df.sort_values('index',inplace=True)
    order_df.loc[:,'Average'] =  (order_df.loc[:,'Gini'] + order_df.loc[:,'Entropy']) / 2 
    order_df.sort_values('Average',inplace=True,ascending=False)

    col_order = order_df.index
    importance = order_df.loc[:,'Average'].values
    
    set_dict[key]['Features'] = {}
    set_dict[key]['Features']['Avg. Importance Scores'] = importance
    set_dict[key]['Features']['Importance Order'] = col_order
    
    fig0,ax = plot_feature_importance(col_order,importance,
                                sort=True,
                                ascending=False,
                                show=False,
                                title_fontsize=20,
                                x_fontsize=20,
                                y_fontsize=20,
                                x_tick_size=20,
                                y_tick_size=20,
                                title='Average Scores, Dataset: {}, Evaluator: {}'.format(key,evaluator));
#     fig0.savefig('{}/{}.png'.format(save_folder,key))
    plt.close('all')
# Out:
# Standard
# Aggregated 1
# Aggregated 2
# Aggregated 3
# Aggregated 4
# Aggregated 1+2
# Aggregated 1+2+4
# Aggregated 1+2+3+4
# Standard 2

# %%
from IPython.display import Image, display
from os import listdir
from os.path import isfile, join

view_folder = '/Users/Martin/Documents/Exjobb final/Plots/Feature Importance/'
onlyfiles = [f for f in listdir(view_folder) if isfile(join(view_folder, f))]

for filename in onlyfiles:
    display(Image(filename=view_folder+'/{}'.format(filename)))

# %%
key ='Standard 2'
set_dict[key]['Features']

min_features = 1
max_features = 30
jump = 1

# for i in [1]:
for key in set_dict.keys():
    print(key)
    set_dict[key]['Features']['Runs'] = {}
    set_dict[key]['Features']['Runs']['Scores'] = {}
    set_dict[key]['Features']['Runs']['All runs'] = {}
    filename = set_dict[key]['filename']
    df = read_data(filename,folder)
    feature_order = set_dict[key]['Features']['Importance Order'].values
    Y = df.pop('Class')
    
    df.loc[:,df.dtypes == 'bool'] = df.loc[:,df.dtypes == 'bool'].astype(int)
    
    no_feats=list(range(min_features,min(max_features,df.shape[1]),jump))
    for i,n_features in enumerate(no_feats):
        print('{}/{}'.format(i+1,len(no_feats)))
        feature_subset = feature_order[0:n_features]
        df_subset = df.loc[:,feature_subset]
        
        Xtrain,Xtest,Ytrain,Ytest = sets = train_test_split(df_subset,Y.values,
                        train_size=0.5,
                        shuffle=False)
        Xtrain,scaler = scale_data(Xtrain,'MinMax')
        Xtest= scaler.transform(Xtest.values)
        
        mets = 0
        score_df = pd.DataFrame()
        for j in range(10): # set range to like 40
            elm = ELM(m=100,w=100,type='wc') # 'standard 2'
            elm.fit(Xtrain.values,Ytrain)
            Ypreds = elm.predict(Xtest)
            met = getMetrics(Ytest,Ypreds)
            mets += met
            
            met.loc['Run'] = j+1
            score_df = score_df.append(met,ignore_index=True)
            
        print(mets/(j+1))
        set_dict[key]['Features']['Runs']['Scores'][n_features] = mets / (j+1)
        set_dict[key]['Features']['Runs']['All runs'][n_features] = score_df
# Out:
# Standard
# 1/24
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Balanced Accuracy       0.560582
# MCC                     0.035137
# Accuracy                0.622906
# F1-Score                0.050197
# Precision               0.026442
# Recall                  0.495652
# True Negatives       1404.900000
# False Positives       841.100000
# False Negatives        23.200000
# True Positives         22.800000
# dtype: float64
# 2/24
# Balanced Accuracy       0.545850
# MCC                     0.032739
# Accuracy                0.800611
# F1-Score                0.053426
# Precision               0.029534
# Recall                  0.280435
# True Negatives       1822.100000
# False Positives       423.900000
# False Negatives        33.100000
# True Positives         12.900000
# dtype: float64
# 3/24
# Balanced Accuracy       0.615113
# MCC                     0.087472
# Accuracy                0.832024
# F1-Score                0.085284
# Precision               0.047921
# Recall                  0.389130
# True Negatives       1889.100000
# False Positives       356.900000
# False Negatives        28.100000
# True Positives         17.900000
# dtype: float64
# 4/24
# Balanced Accuracy       0.614553
# MCC                     0.089315
# Accuracy                0.841361
# F1-Score                0.087645
# Precision               0.049596
# Recall                  0.378261
# True Negatives       1911.000000
# False Positives       335.000000
# False Negatives        28.600000
# True Positives         17.400000
# dtype: float64
# 5/24
# Balanced Accuracy       0.585495
# MCC                     0.067276
# Accuracy                0.840750
# F1-Score                0.075136
# Precision               0.042624
# Recall                  0.319565
# True Negatives       1912.300000
# False Positives       333.700000
# False Negatives        31.300000
# True Positives         14.700000
# dtype: float64
# 6/24
# Balanced Accuracy       0.613954
# MCC                     0.095386
# Accuracy                0.865227
# F1-Score                0.094905
# Precision               0.054874
# Recall                  0.352174
# True Negatives       1966.900000
# False Positives       279.100000
# False Negatives        29.800000
# True Positives         16.200000
# dtype: float64
# 7/24
# Balanced Accuracy       0.614716
# MCC                     0.101121
# Accuracy                0.881326
# F1-Score                0.101177
# Precision               0.059704
# Recall                  0.336957
# True Negatives       2004.500000
# False Positives       241.500000
# False Negatives        30.500000
# True Positives         15.500000
# dtype: float64
# 8/24
# Balanced Accuracy       0.580257
# MCC                     0.073542
# Accuracy                0.886824
# F1-Score                0.084244
# Precision               0.050255
# Recall                  0.260870
# True Negatives       2020.600000
# False Positives       225.400000
# False Negatives        34.000000
# True Positives         12.000000
# dtype: float64
# 9/24
# Balanced Accuracy       0.617001
# MCC                     0.104643
# Accuracy                0.881632
# F1-Score                0.104475
# Precision               0.061786
# Recall                  0.341304
# True Negatives       2005.000000
# False Positives       241.000000
# False Negatives        30.300000
# True Positives         15.700000
# dtype: float64
# 10/24
# Balanced Accuracy       0.584534
# MCC                     0.077785
# Accuracy                0.884773
# F1-Score                0.087430
# Precision               0.052309
# Recall                  0.271739
# True Negatives       2015.400000
# False Positives       230.600000
# False Negatives        33.500000
# True Positives         12.500000
# dtype: float64
# 11/24
# Balanced Accuracy       0.594349
# MCC                     0.084417
# Accuracy                0.878970
# F1-Score                0.090900
# Precision               0.053777
# Recall                  0.297826
# True Negatives       2000.900000
# False Positives       245.100000
# False Negatives        32.300000
# True Positives         13.700000
# dtype: float64
# 12/24
# Balanced Accuracy       0.578632
# MCC                     0.070085
# Accuracy                0.883639
# F1-Score                0.080778
# Precision               0.047936
# Recall                  0.260870
# True Negatives       2013.300000
# False Positives       232.700000
# False Negatives        34.000000
# True Positives         12.000000
# dtype: float64
# 13/24
# Balanced Accuracy       0.568318
# MCC                     0.059468
# Accuracy                0.871771
# F1-Score                0.073300
# Precision               0.042965
# Recall                  0.252174
# True Negatives       1986.500000
# False Positives       259.500000
# False Negatives        34.400000
# True Positives         11.600000
# dtype: float64
# 14/24
# Balanced Accuracy       0.579147
# MCC                     0.069495
# Accuracy                0.874215
# F1-Score                0.080200
# Precision               0.047146
# Recall                  0.271739
# True Negatives       1991.200000
# False Positives       254.800000
# False Negatives        33.500000
# True Positives         12.500000
# dtype: float64
# 15/24
# Balanced Accuracy       0.593395
# MCC                     0.079118
# Accuracy                0.866667
# F1-Score                0.085115
# Precision               0.049445
# Recall                  0.308696
# True Negatives       1972.200000
# False Positives       273.800000
# False Negatives        31.800000
# True Positives         14.200000
# dtype: float64
# 16/24
# Balanced Accuracy       0.569263
# MCC                     0.059209
# Accuracy                0.867365
# F1-Score                0.072608
# Precision               0.042325
# Recall                  0.258696
# True Negatives       1976.100000
# False Positives       269.900000
# False Negatives        34.100000
# True Positives         11.900000
# dtype: float64
# 17/24
# Balanced Accuracy       0.568072
# MCC                     0.056250
# Accuracy                0.858770
# F1-Score                0.069827
# Precision               0.040272
# Recall                  0.265217
# True Negatives       1956.100000
# False Positives       289.900000
# False Negatives        33.800000
# True Positives         12.200000
# dtype: float64
# 18/24
# Balanced Accuracy       0.557080
# MCC                     0.048056
# Accuracy                0.864354
# F1-Score                0.065061
# Precision               0.037760
# Recall                  0.236957
# True Negatives       1970.200000
# False Positives       275.800000
# False Negatives        35.100000
# True Positives         10.900000
# dtype: float64
# 19/24
# Balanced Accuracy       0.561614
# MCC                     0.053265
# Accuracy                0.869066
# F1-Score                0.069079
# Precision               0.040422
# Recall                  0.241304
# True Negatives       1980.800000
# False Positives       265.200000
# False Negatives        34.900000
# True Positives         11.100000
# dtype: float64
# 20/24
# Balanced Accuracy       0.572783
# MCC                     0.061456
# Accuracy                0.863831
# F1-Score                0.073763
# Precision               0.042796
# Recall                  0.269565
# True Negatives       1967.500000
# False Positives       278.500000
# False Negatives        33.600000
# True Positives         12.400000
# dtype: float64
# 21/24
# Balanced Accuracy       0.589585
# MCC                     0.076604
# Accuracy                0.869634
# F1-Score                0.083849
# Precision               0.048877
# Recall                  0.297826
# True Negatives       1979.500000
# False Positives       266.500000
# False Negatives        32.300000
# True Positives         13.700000
# dtype: float64
# 22/24
# Balanced Accuracy       0.574037
# MCC                     0.060993
# Accuracy                0.857941
# F1-Score                0.072696
# Precision               0.041899
# Recall                  0.278261
# True Negatives       1953.600000
# False Positives       292.400000
# False Negatives        33.200000
# True Positives         12.800000
# dtype: float64
# 23/24
# Balanced Accuracy       0.575940
# MCC                     0.062230
# Accuracy                0.855410
# F1-Score                0.073358
# Precision               0.042144
# Recall                  0.284783
# True Negatives       1947.500000
# False Positives       298.500000
# False Negatives        32.900000
# True Positives         13.100000
# dtype: float64
# 24/24
# Balanced Accuracy       0.562548
# MCC                     0.051892
# Accuracy                0.858377
# F1-Score                0.067239
# Precision               0.038814
# Recall                  0.254348
# True Negatives       1955.700000
# False Positives       290.300000
# False Negatives        34.300000
# True Positives         11.700000
# dtype: float64
# Aggregated 1
# 1/29
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Balanced Accuracy       0.567281
# MCC                     0.038821
# Accuracy                0.610995
# F1-Score                0.051051
# Precision               0.026853
# Recall                  0.521739
# True Negatives       1376.400000
# False Positives       869.600000
# False Negatives        22.000000
# True Positives         24.000000
# dtype: float64
# 2/29
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Balanced Accuracy       0.589696
# MCC                     0.061714
# Accuracy                0.761344
# F1-Score                0.067444
# Precision               0.036854
# Recall                  0.410870
# True Negatives       1726.100000
# False Positives       519.900000
# False Negatives        27.100000
# True Positives         18.900000
# dtype: float64
# 3/29
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Balanced Accuracy       0.574874
# MCC                     0.052946
# Accuracy                0.794895
# F1-Score                0.063737
# Precision               0.035140
# Recall                  0.345652
# True Negatives       1806.000000
# False Positives       440.000000
# False Negatives        30.100000
# True Positives         15.900000
# dtype: float64
# 4/29
# Balanced Accuracy       0.607385
# MCC                     0.093284
# Accuracy                0.875305
# F1-Score                0.095373
# Precision               0.055839
# Recall                  0.328261
# True Negatives       1991.100000
# False Positives       254.900000
# False Negatives        30.900000
# True Positives         15.100000
# dtype: float64
# 5/29
# Balanced Accuracy       0.631531
# MCC                     0.111604
# Accuracy                0.870462
# F1-Score                0.105970
# Precision               0.061533
# Recall                  0.382609
# True Negatives       1977.500000
# False Positives       268.500000
# False Negatives        28.400000
# True Positives         17.600000
# dtype: float64
# 6/29
# Balanced Accuracy       0.611923
# MCC                     0.099976
# Accuracy                0.882112
# F1-Score                0.101208
# Precision               0.059868
# Recall                  0.330435
# True Negatives       2006.600000
# False Positives       239.400000
# False Negatives        30.800000
# True Positives         15.200000
# dtype: float64
# 7/29
# Balanced Accuracy       0.624881
# MCC                     0.111906
# Accuracy                0.884555
# F1-Score                0.109391
# Precision               0.064757
# Recall                  0.354348
# True Negatives       2011.100000
# False Positives       234.900000
# False Negatives        29.700000
# True Positives         16.300000
# dtype: float64
# 8/29
# Balanced Accuracy       0.623660
# MCC                     0.109986
# Accuracy                0.884250
# F1-Score                0.107592
# Precision               0.063669
# Recall                  0.352174
# True Negatives       2010.500000
# False Positives       235.500000
# False Negatives        29.800000
# True Positives         16.200000
# dtype: float64
# 9/29
# Balanced Accuracy       0.634077
# MCC                     0.117844
# Accuracy                0.879625
# F1-Score                0.112233
# Precision               0.066014
# Recall                  0.378261
# True Negatives       1998.700000
# False Positives       247.300000
# False Negatives        28.600000
# True Positives         17.400000
# dtype: float64
# 10/29
# Balanced Accuracy       0.614935
# MCC                     0.099867
# Accuracy                0.879668
# F1-Score                0.099518
# Precision               0.058374
# Recall                  0.339130
# True Negatives       2000.600000
# False Positives       245.400000
# False Negatives        30.400000
# True Positives         15.600000
# dtype: float64
# 11/29
# Balanced Accuracy       0.632005
# MCC                     0.126258
# Accuracy                0.898517
# F1-Score                0.123358
# Precision               0.075008
# Recall                  0.354348
# True Negatives       2043.100000
# False Positives       202.900000
# False Negatives        29.700000
# True Positives         16.300000
# dtype: float64
# 12/29
# Balanced Accuracy       0.645467
# MCC                     0.137012
# Accuracy                0.897775
# F1-Score                0.129904
# Precision               0.078352
# Recall                  0.382609
# True Negatives       2040.100000
# False Positives       205.900000
# False Negatives        28.400000
# True Positives         17.600000
# dtype: float64
# 13/29
# Balanced Accuracy       0.637788
# MCC                     0.129262
# Accuracy                0.895244
# F1-Score                0.124248
# Precision               0.074823
# Recall                  0.369565
# True Negatives       2034.900000
# False Positives       211.100000
# False Negatives        29.000000
# True Positives         17.000000
# dtype: float64
# 14/29
# Balanced Accuracy       0.672889
# MCC                     0.156328
# Accuracy                0.888918
# F1-Score                0.140216
# Precision               0.083274
# Recall                  0.447826
# True Negatives       2016.800000
# False Positives       229.200000
# False Negatives        25.400000
# True Positives         20.600000
# dtype: float64
# 15/29
# Balanced Accuracy       0.636333
# MCC                     0.124090
# Accuracy                0.888220
# F1-Score                0.118681
# Precision               0.070645
# Recall                  0.373913
# True Negatives       2018.600000
# False Positives       227.400000
# False Negatives        28.800000
# True Positives         17.200000
# dtype: float64
# 16/29
# Balanced Accuracy       0.623502
# MCC                     0.116399
# Accuracy                0.894372
# F1-Score                0.115501
# Precision               0.069689
# Recall                  0.341304
# True Negatives       2034.200000
# False Positives       211.800000
# False Negatives        30.300000
# True Positives         15.700000
# dtype: float64
# 17/29
# Balanced Accuracy       0.626095
# MCC                     0.118167
# Accuracy                0.893194
# F1-Score                0.116403
# Precision               0.070173
# Recall                  0.347826
# True Negatives       2031.200000
# False Positives       214.800000
# False Negatives        30.000000
# True Positives         16.000000
# dtype: float64
# 18/29
# Balanced Accuracy       0.630165
# MCC                     0.124104
# Accuracy                0.899084
# F1-Score                0.121551
# Precision               0.073776
# Recall                  0.350000
# True Negatives       2044.600000
# False Positives       201.400000
# False Negatives        29.900000
# True Positives         16.100000
# dtype: float64
# 19/29
# Balanced Accuracy       0.615904
# MCC                     0.106421
# Accuracy                0.887827
# F1-Score                0.107097
# Precision               0.063940
# Recall                  0.332609
# True Negatives       2019.600000
# False Positives       226.400000
# False Negatives        30.700000
# True Positives         15.300000
# dtype: float64
# 20/29
# Balanced Accuracy       0.638367
# MCC                     0.131967
# Accuracy                0.896379
# F1-Score                0.127392
# Precision               0.077080
# Recall                  0.369565
# True Negatives       2037.500000
# False Positives       208.500000
# False Negatives        29.000000
# True Positives         17.000000
# dtype: float64
# 21/29
# Balanced Accuracy       0.636007
# MCC                     0.125803
# Accuracy                0.891754
# F1-Score                0.120888
# Precision               0.072588
# Recall                  0.369565
# True Negatives       2026.900000
# False Positives       219.100000
# False Negatives        29.000000
# True Positives         17.000000
# dtype: float64
# 22/29
# Balanced Accuracy       0.648029
# MCC                     0.129863
# Accuracy                0.879843
# F1-Score                0.120070
# Precision               0.070582
# Recall                  0.406522
# True Negatives       1997.900000
# False Positives       248.100000
# False Negatives        27.300000
# True Positives         18.700000
# dtype: float64
# 23/29
# Balanced Accuracy       0.615537
# MCC                     0.107015
# Accuracy                0.893368
# F1-Score                0.107749
# Precision               0.064720
# Recall                  0.326087
# True Negatives       2032.600000
# False Positives       213.400000
# False Negatives        31.000000
# True Positives         15.000000
# dtype: float64
# 24/29
# Balanced Accuracy       0.626117
# MCC                     0.118714
# Accuracy                0.893237
# F1-Score                0.117125
# Precision               0.070571
# Recall                  0.347826
# True Negatives       2031.300000
# False Positives       214.700000
# False Negatives        30.000000
# True Positives         16.000000
# dtype: float64
# 25/29
# Balanced Accuracy       0.615955
# MCC                     0.102965
# Accuracy                0.879581
# F1-Score                0.102938
# Precision               0.060821
# Recall                  0.341304
# True Negatives       2000.300000
# False Positives       245.700000
# False Negatives        30.300000
# True Positives         15.700000
# dtype: float64
# 26/29
# Balanced Accuracy       0.641668
# MCC                     0.130916
# Accuracy                0.894503
# F1-Score                0.124253
# Precision               0.074484
# Recall                  0.378261
# True Negatives       2032.800000
# False Positives       213.200000
# False Negatives        28.600000
# True Positives         17.400000
# dtype: float64
# 27/29
# Balanced Accuracy       0.616663
# MCC                     0.102152
# Accuracy                0.878883
# F1-Score                0.101559
# Precision               0.059697
# Recall                  0.343478
# True Negatives       1998.600000
# False Positives       247.400000
# False Negatives        30.200000
# True Positives         15.800000
# dtype: float64
# 28/29
# Balanced Accuracy       0.617595
# MCC                     0.103686
# Accuracy                0.878621
# F1-Score                0.103034
# Precision               0.060702
# Recall                  0.345652
# True Negatives       1997.900000
# False Positives       248.100000
# False Negatives        30.100000
# True Positives         15.900000
# dtype: float64
# 29/29
# Balanced Accuracy       0.617813
# MCC                     0.102206
# Accuracy                0.876963
# F1-Score                0.101053
# Precision               0.059339
# Recall                  0.347826
# True Negatives       1994.000000
# False Positives       252.000000
# False Negatives        30.000000
# True Positives         16.000000
# dtype: float64
# Aggregated 2
# 1/29
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Balanced Accuracy       0.551249
# MCC                     0.029796
# Accuracy                0.625480
# F1-Score                0.048442
# Precision               0.025529
# Recall                  0.473913
# True Negatives       1411.800000
# False Positives       834.200000
# False Negatives        24.200000
# True Positives         21.800000
# dtype: float64
# 2/29
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Balanced Accuracy       0.622323
# MCC                     0.080600
# Accuracy                0.760602
# F1-Score                0.074352
# Precision               0.040313
# Recall                  0.478261
# True Negatives       1721.300000
# False Positives       524.700000
# False Negatives        24.000000
# True Positives         22.000000
# dtype: float64
# 3/29
# Balanced Accuracy       0.587320
# MCC                     0.068847
# Accuracy                0.844328
# F1-Score                0.076064
# Precision               0.043194
# Recall                  0.319565
# True Negatives       1920.500000
# False Positives       325.500000
# False Negatives        31.300000
# True Positives         14.700000
# dtype: float64
# 4/29
# Balanced Accuracy       0.582085
# MCC                     0.062915
# Accuracy                0.831981
# F1-Score                0.071682
# Precision               0.040353
# Recall                  0.321739
# True Negatives       1892.100000
# False Positives       353.900000
# False Negatives        31.200000
# True Positives         14.800000
# dtype: float64
# 5/29
# Balanced Accuracy       0.568240
# MCC                     0.052219
# Accuracy                0.829887
# F1-Score                0.065521
# Precision               0.036870
# Recall                  0.295652
# True Negatives       1888.500000
# False Positives       357.500000
# False Negatives        32.400000
# True Positives         13.600000
# dtype: float64
# 6/29
# Balanced Accuracy       0.613729
# MCC                     0.085511
# Accuracy                0.827225
# F1-Score                0.083652
# Precision               0.046906
# Recall                  0.391304
# True Negatives       1878.000000
# False Positives       368.000000
# False Negatives        28.000000
# True Positives         18.000000
# dtype: float64
# 7/29
# Balanced Accuracy       0.606800
# MCC                     0.081350
# Accuracy                0.834511
# F1-Score                0.081874
# Precision               0.046055
# Recall                  0.369565
# True Negatives       1895.700000
# False Positives       350.300000
# False Negatives        29.000000
# True Positives         17.000000
# dtype: float64
# 8/29
# Balanced Accuracy       0.608635
# MCC                     0.091580
# Accuracy                0.867321
# F1-Score                0.092828
# Precision               0.053826
# Recall                  0.339130
# True Negatives       1972.300000
# False Positives       273.700000
# False Negatives        30.400000
# True Positives         15.600000
# dtype: float64
# 9/29
# Balanced Accuracy       0.592887
# MCC                     0.078966
# Accuracy                0.867757
# F1-Score                0.085160
# Precision               0.049531
# Recall                  0.306522
# True Negatives       1974.800000
# False Positives       271.200000
# False Negatives        31.900000
# True Positives         14.100000
# dtype: float64
# 10/29
# Balanced Accuracy       0.587008
# MCC                     0.077514
# Accuracy                0.879188
# F1-Score                0.086017
# Precision               0.050825
# Recall                  0.282609
# True Negatives       2002.100000
# False Positives       243.900000
# False Negatives        33.000000
# True Positives         13.000000
# dtype: float64
# 11/29
# Balanced Accuracy       0.572584
# MCC                     0.063623
# Accuracy                0.875960
# F1-Score                0.076120
# Precision               0.044789
# Recall                  0.256522
# True Negatives       1995.900000
# False Positives       250.100000
# False Negatives        34.200000
# True Positives         11.800000
# dtype: float64
# 12/29
# Balanced Accuracy       0.553976
# MCC                     0.047813
# Accuracy                0.877051
# F1-Score                0.065898
# Precision               0.038889
# Recall                  0.217391
# True Negatives       2000.200000
# False Positives       245.800000
# False Negatives        36.000000
# True Positives         10.000000
# dtype: float64
# 13/29
# Balanced Accuracy       0.592198
# MCC                     0.081607
# Accuracy                0.878927
# F1-Score                0.088464
# Precision               0.052152
# Recall                  0.293478
# True Negatives       2001.000000
# False Positives       245.000000
# False Negatives        32.500000
# True Positives         13.500000
# dtype: float64
# 14/29
# Balanced Accuracy       0.583446
# MCC                     0.072732
# Accuracy                0.872208
# F1-Score                0.082097
# Precision               0.048086
# Recall                  0.282609
# True Negatives       1986.100000
# False Positives       259.900000
# False Negatives        33.000000
# True Positives         13.000000
# dtype: float64
# 15/29
# Balanced Accuracy       0.589127
# MCC                     0.081557
# Accuracy                0.885428
# F1-Score                0.089777
# Precision               0.053526
# Recall                  0.280435
# True Negatives       2016.500000
# False Positives       229.500000
# False Negatives        33.100000
# True Positives         12.900000
# dtype: float64
# 16/29
# Balanced Accuracy       0.578668
# MCC                     0.070530
# Accuracy                0.879538
# F1-Score                0.081545
# Precision               0.048331
# Recall                  0.265217
# True Negatives       2003.700000
# False Positives       242.300000
# False Negatives        33.800000
# True Positives         12.200000
# dtype: float64
# 17/29
# Balanced Accuracy       0.573900
# MCC                     0.063058
# Accuracy                0.868106
# F1-Score                0.075019
# Precision               0.043709
# Recall                  0.267391
# True Negatives       1977.400000
# False Positives       268.600000
# False Negatives        33.700000
# True Positives         12.300000
# dtype: float64
# 18/29
# Balanced Accuracy       0.591255
# MCC                     0.078558
# Accuracy                0.872906
# F1-Score                0.085300
# Precision               0.049831
# Recall                  0.297826
# True Negatives       1987.000000
# False Positives       259.000000
# False Negatives        32.300000
# True Positives         13.700000
# dtype: float64
# 19/29
# Balanced Accuracy       0.577076
# MCC                     0.066169
# Accuracy                0.870157
# F1-Score                0.077211
# Precision               0.045072
# Recall                  0.271739
# True Negatives       1981.900000
# False Positives       264.100000
# False Negatives        33.500000
# True Positives         12.500000
# dtype: float64
# 20/29
# Balanced Accuracy       0.578701
# MCC                     0.069155
# Accuracy                0.873342
# F1-Score                0.080063
# Precision               0.046983
# Recall                  0.271739
# True Negatives       1989.200000
# False Positives       256.800000
# False Negatives        33.500000
# True Positives         12.500000
# dtype: float64
# 21/29
# Balanced Accuracy       0.568221
# MCC                     0.057981
# Accuracy                0.867408
# F1-Score                0.071615
# Precision               0.041715
# Recall                  0.256522
# True Negatives       1976.300000
# False Positives       269.700000
# False Negatives        34.200000
# True Positives         11.800000
# dtype: float64
# 22/29
# Balanced Accuracy       0.555226
# MCC                     0.047471
# Accuracy                0.869066
# F1-Score                0.065127
# Precision               0.038052
# Recall                  0.228261
# True Negatives       1981.400000
# False Positives       264.600000
# False Negatives        35.500000
# True Positives         10.500000
# dtype: float64
# 23/29
# Balanced Accuracy       0.571577
# MCC                     0.059447
# Accuracy                0.859380
# F1-Score                0.071996
# Precision               0.041550
# Recall                  0.271739
# True Negatives       1957.200000
# False Positives       288.800000
# False Negatives        33.500000
# True Positives         12.500000
# dtype: float64
# 24/29
# Balanced Accuracy       0.561005
# MCC                     0.051926
# Accuracy                0.863700
# F1-Score                0.067894
# Precision               0.039492
# Recall                  0.245652
# True Negatives       1968.300000
# False Positives       277.700000
# False Negatives        34.700000
# True Positives         11.300000
# dtype: float64
# 25/29
# Balanced Accuracy       0.578674
# MCC                     0.065337
# Accuracy                0.858682
# F1-Score                0.075738
# Precision               0.043674
# Recall                  0.286957
# True Negatives       1954.900000
# False Positives       291.100000
# False Negatives        32.800000
# True Positives         13.200000
# dtype: float64
# 26/29
# Balanced Accuracy       0.598614
# MCC                     0.081398
# Accuracy                0.858115
# F1-Score                0.085529
# Precision               0.049260
# Recall                  0.328261
# True Negatives       1951.700000
# False Positives       294.300000
# False Negatives        30.900000
# True Positives         15.100000
# dtype: float64
# 27/29
# Balanced Accuracy       0.563917
# MCC                     0.054043
# Accuracy                0.867321
# F1-Score                0.068900
# Precision               0.040078
# Recall                  0.247826
# True Negatives       1976.500000
# False Positives       269.500000
# False Negatives        34.600000
# True Positives         11.400000
# dtype: float64
# 28/29
# Balanced Accuracy       0.567727
# MCC                     0.058426
# Accuracy                0.864354
# F1-Score                0.072568
# Precision               0.042313
# Recall                  0.258696
# True Negatives       1969.200000
# False Positives       276.800000
# False Negatives        34.100000
# True Positives         11.900000
# dtype: float64
# 29/29
# Balanced Accuracy       0.565319
# MCC                     0.053545
# Accuracy                0.857548
# F1-Score                0.067909
# Precision               0.039063
# Recall                  0.260870
# True Negatives       1953.500000
# False Positives       292.500000
# False Negatives        34.000000
# True Positives         12.000000
# dtype: float64
# Aggregated 3
# 1/29
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Balanced Accuracy       0.559790
# MCC                     0.034450
# Accuracy                0.602574
# F1-Score                0.049728
# Precision               0.026133
# Recall                  0.515217
# True Negatives       1357.400000
# False Positives       888.600000
# False Negatives        22.300000
# True Positives         23.700000
# dtype: float64
# 2/29
# Balanced Accuracy       0.546603
# MCC                     0.033239
# Accuracy                0.800000
# F1-Score                0.053671
# Precision               0.029661
# Recall                  0.282609
# True Negatives       1820.600000
# False Positives       425.400000
# False Negatives        33.000000
# True Positives         13.000000
# dtype: float64
# 3/29
# Balanced Accuracy       0.581106
# MCC                     0.062006
# Accuracy                0.830061
# F1-Score                0.071097
# Precision               0.039989
# Recall                  0.321739
# True Negatives       1887.700000
# False Positives       358.300000
# False Negatives        31.200000
# True Positives         14.800000
# dtype: float64
# 4/29
# Balanced Accuracy       0.581854
# MCC                     0.068957
# Accuracy                0.862827
# F1-Score                0.078491
# Precision               0.045477
# Recall                  0.289130
# True Negatives       1964.300000
# False Positives       281.700000
# False Negatives        32.700000
# True Positives         13.300000
# dtype: float64
# 5/29
# Balanced Accuracy       0.563443
# MCC                     0.056133
# Accuracy                0.874738
# F1-Score                0.071554
# Precision               0.042115
# Recall                  0.239130
# True Negatives       1993.900000
# False Positives       252.100000
# False Negatives        35.000000
# True Positives         11.000000
# dtype: float64
# 6/29
# Balanced Accuracy       0.590117
# MCC                     0.081412
# Accuracy                0.881108
# F1-Score                0.089280
# Precision               0.052909
# Recall                  0.286957
# True Negatives       2006.300000
# False Positives       239.700000
# False Negatives        32.800000
# True Positives         13.200000
# dtype: float64
# 7/29
# Balanced Accuracy       0.592631
# MCC                     0.080092
# Accuracy                0.873517
# F1-Score                0.086510
# Precision               0.050634
# Recall                  0.300000
# True Negatives       1988.300000
# False Positives       257.700000
# False Negatives        32.200000
# True Positives         13.800000
# dtype: float64
# 8/29
# Balanced Accuracy       0.586351
# MCC                     0.074863
# Accuracy                0.871640
# F1-Score                0.083293
# Precision               0.048753
# Recall                  0.289130
# True Negatives       1984.500000
# False Positives       261.500000
# False Negatives        32.700000
# True Positives         13.300000
# dtype: float64
# 9/29
# Balanced Accuracy       0.607333
# MCC                     0.092368
# Accuracy                0.871030
# F1-Score                0.094397
# Precision               0.055089
# Recall                  0.332609
# True Negatives       1981.100000
# False Positives       264.900000
# False Negatives        30.700000
# True Positives         15.300000
# dtype: float64
# 10/29
# Balanced Accuracy       0.598352
# MCC                     0.085062
# Accuracy                0.872208
# F1-Score                0.089849
# Precision               0.052520
# Recall                  0.313043
# True Negatives       1984.700000
# False Positives       261.300000
# False Negatives        31.600000
# True Positives         14.400000
# dtype: float64
# 11/29
# Balanced Accuracy       0.603820
# MCC                     0.091999
# Accuracy                0.878752
# F1-Score                0.095518
# Precision               0.056261
# Recall                  0.317391
# True Negatives       1999.500000
# False Positives       246.500000
# False Negatives        31.400000
# True Positives         14.600000
# dtype: float64
# 12/29
# Balanced Accuracy       0.592965
# MCC                     0.080466
# Accuracy                0.874171
# F1-Score                0.086789
# Precision               0.050789
# Recall                  0.300000
# True Negatives       1989.800000
# False Positives       256.200000
# False Negatives        32.200000
# True Positives         13.800000
# dtype: float64
# 13/29
# Balanced Accuracy       0.570662
# MCC                     0.060792
# Accuracy                0.868019
# F1-Score                0.073898
# Precision               0.043120
# Recall                  0.260870
# True Negatives       1977.500000
# False Positives       268.500000
# False Negatives        34.000000
# True Positives         12.000000
# dtype: float64
# 14/29
# Balanced Accuracy       0.583286
# MCC                     0.072877
# Accuracy                0.869808
# F1-Score                0.082451
# Precision               0.048359
# Recall                  0.284783
# True Negatives       1980.500000
# False Positives       265.500000
# False Negatives        32.900000
# True Positives         13.100000
# dtype: float64
# 15/29
# Balanced Accuracy       0.575529
# MCC                     0.065305
# Accuracy                0.873386
# F1-Score                0.076824
# Precision               0.044956
# Recall                  0.265217
# True Negatives       1989.600000
# False Positives       256.400000
# False Negatives        33.800000
# True Positives         12.200000
# dtype: float64
# 16/29
# Balanced Accuracy       0.606086
# MCC                     0.090017
# Accuracy                0.868586
# F1-Score                0.092146
# Precision               0.053565
# Recall                  0.332609
# True Negatives       1975.500000
# False Positives       270.500000
# False Negatives        30.700000
# True Positives         15.300000
# dtype: float64
# 17/29
# Balanced Accuracy       0.580986
# MCC                     0.068188
# Accuracy                0.861126
# F1-Score                0.078019
# Precision               0.045228
# Recall                  0.289130
# True Negatives       1960.400000
# False Positives       285.600000
# False Negatives        32.700000
# True Positives         13.300000
# dtype: float64
# 18/29
# Balanced Accuracy       0.593840
# MCC                     0.079884
# Accuracy                0.867539
# F1-Score                0.085825
# Precision               0.049941
# Recall                  0.308696
# True Negatives       1974.200000
# False Positives       271.800000
# False Negatives        31.800000
# True Positives         14.200000
# dtype: float64
# 19/29
# Balanced Accuracy       0.582536
# MCC                     0.069404
# Accuracy                0.859991
# F1-Score                0.078784
# Precision               0.045636
# Recall                  0.293478
# True Negatives       1957.600000
# False Positives       288.400000
# False Negatives        32.500000
# True Positives         13.500000
# dtype: float64
# 20/29
# Balanced Accuracy       0.580040
# MCC                     0.067097
# Accuracy                0.865532
# F1-Score                0.076977
# Precision               0.044640
# Recall                  0.282609
# True Negatives       1970.800000
# False Positives       275.200000
# False Negatives        33.000000
# True Positives         13.000000
# dtype: float64
# 21/29
# Balanced Accuracy       0.575621
# MCC                     0.063304
# Accuracy                0.863133
# F1-Score                0.074616
# Precision               0.043178
# Recall                  0.276087
# True Negatives       1965.600000
# False Positives       280.400000
# False Negatives        33.300000
# True Positives         12.700000
# dtype: float64
# 22/29
# Balanced Accuracy       0.581275
# MCC                     0.067923
# Accuracy                0.861693
# F1-Score                0.077528
# Precision               0.044827
# Recall                  0.289130
# True Negatives       1961.700000
# False Positives       284.300000
# False Negatives        32.700000
# True Positives         13.300000
# dtype: float64
# 23/29
# Balanced Accuracy       0.589964
# MCC                     0.077499
# Accuracy                0.870375
# F1-Score                0.084769
# Precision               0.049475
# Recall                  0.297826
# True Negatives       1981.200000
# False Positives       264.800000
# False Negatives        32.300000
# True Positives         13.700000
# dtype: float64
# 24/29
# Balanced Accuracy       0.599549
# MCC                     0.082107
# Accuracy                0.859948
# F1-Score                0.085869
# Precision               0.049483
# Recall                  0.328261
# True Negatives       1955.900000
# False Positives       290.100000
# False Negatives        30.900000
# True Positives         15.100000
# dtype: float64
# 25/29
# Balanced Accuracy       0.589718
# MCC                     0.074326
# Accuracy                0.857373
# F1-Score                0.081306
# Precision               0.046887
# Recall                  0.310870
# True Negatives       1950.800000
# False Positives       295.200000
# False Negatives        31.700000
# True Positives         14.300000
# dtype: float64
# 26/29
# Balanced Accuracy       0.582221
# MCC                     0.067344
# Accuracy                0.857286
# F1-Score                0.076423
# Precision               0.043972
# Recall                  0.295652
# True Negatives       1951.300000
# False Positives       294.700000
# False Negatives        32.400000
# True Positives         13.600000
# dtype: float64
# 27/29
# Balanced Accuracy       0.588175
# MCC                     0.074162
# Accuracy                0.862696
# F1-Score                0.081711
# Precision               0.047384
# Recall                  0.302174
# True Negatives       1963.400000
# False Positives       282.600000
# False Negatives        32.100000
# True Positives         13.900000
# dtype: float64
# 28/29
# Balanced Accuracy       0.581048
# MCC                     0.067321
# Accuracy                0.859162
# F1-Score                0.076952
# Precision               0.044454
# Recall                  0.291304
# True Negatives       1955.800000
# False Positives       290.200000
# False Negatives        32.600000
# True Positives         13.400000
# dtype: float64
# 29/29
# Balanced Accuracy       0.577053
# MCC                     0.063790
# Accuracy                0.857592
# F1-Score                0.074657
# Precision               0.043031
# Recall                  0.284783
# True Negatives       1952.500000
# False Positives       293.500000
# False Negatives        32.900000
# True Positives         13.100000
# dtype: float64
# Aggregated 4
# 1/29
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Balanced Accuracy       0.563038
# MCC                     0.036415
# Accuracy                0.619372
# F1-Score                0.050489
# Precision               0.026576
# Recall                  0.504348
# True Negatives       1396.400000
# False Positives       849.600000
# False Negatives        22.800000
# True Positives         23.200000
# dtype: float64
# 2/29
# Balanced Accuracy       0.623681
# MCC                     0.081819
# Accuracy                0.763264
# F1-Score                0.075129
# Precision               0.040775
# Recall                  0.478261
# True Negatives       1727.400000
# False Positives       518.600000
# False Negatives        24.000000
# True Positives         22.000000
# dtype: float64
# 3/29
# ...
# dtype: float64
# 17/29
# Balanced Accuracy       0.643245
# MCC                     0.133993
# Accuracy                0.895506
# F1-Score                0.127345
# Precision               0.076581
# Recall                  0.380435
# True Negatives       2035.000000
# False Positives       211.000000
# False Negatives        28.500000
# True Positives         17.500000
# dtype: float64
# 18/29
# Balanced Accuracy       0.646988
# MCC                     0.135179
# Accuracy                0.892408
# F1-Score                0.126953
# Precision               0.075844
# Recall                  0.391304
# True Negatives       2027.400000
# False Positives       218.600000
# False Negatives        28.000000
# True Positives         18.000000
# dtype: float64
# 19/29
# Balanced Accuracy       0.653402
# MCC                     0.142538
# Accuracy                0.894546
# F1-Score                0.132857
# Precision               0.079654
# Recall                  0.402174
# True Negatives       2031.800000
# False Positives       214.200000
# False Negatives        27.500000
# True Positives         18.500000
# dtype: float64
# 20/29
# Balanced Accuracy       0.657832
# MCC                     0.153415
# Accuracy                0.903229
# F1-Score                0.144115
# Precision               0.087910
# Recall                  0.402174
# True Negatives       2051.700000
# False Positives       194.300000
# False Negatives        27.500000
# True Positives         18.500000
# dtype: float64
# 21/29
# Balanced Accuracy       0.657616
# MCC                     0.145586
# Accuracy                0.894459
# F1-Score                0.134457
# Precision               0.080556
# Recall                  0.410870
# True Negatives       2031.200000
# False Positives       214.800000
# False Negatives        27.100000
# True Positives         18.900000
# dtype: float64
# 22/29
# Balanced Accuracy       0.653009
# MCC                     0.147541
# Accuracy                0.897949
# F1-Score                0.139405
# Precision               0.084780
# Recall                  0.397826
# True Negatives       2039.800000
# False Positives       206.200000
# False Negatives        27.700000
# True Positives         18.300000
# dtype: float64
# 23/29
# Balanced Accuracy       0.643494
# MCC                     0.136761
# Accuracy                0.898080
# F1-Score                0.130686
# Precision               0.079138
# Recall                  0.378261
# True Negatives       2041.000000
# False Positives       205.000000
# False Negatives        28.600000
# True Positives         17.400000
# dtype: float64
# 24/29
# Balanced Accuracy       0.678186
# MCC                     0.158741
# Accuracy                0.886780
# F1-Score                0.140505
# Precision               0.083004
# Recall                  0.460870
# True Negatives       2011.300000
# False Positives       234.700000
# False Negatives        24.800000
# True Positives         21.200000
# dtype: float64
# 25/29
# Balanced Accuracy       0.648012
# MCC                     0.138450
# Accuracy                0.894415
# F1-Score                0.130547
# Precision               0.078559
# Recall                  0.391304
# True Negatives       2032.000000
# False Positives       214.000000
# False Negatives        28.000000
# True Positives         18.000000
# dtype: float64
# 26/29
# Balanced Accuracy       0.654908
# MCC                     0.143241
# Accuracy                0.893325
# F1-Score                0.132968
# Precision               0.079744
# Recall                  0.406522
# True Negatives       2028.800000
# False Positives       217.200000
# False Negatives        27.300000
# True Positives         18.700000
# dtype: float64
# 27/29
# Balanced Accuracy       0.599514
# MCC                     0.091087
# Accuracy                0.889092
# F1-Score                0.096115
# Precision               0.057626
# Recall                  0.297826
# True Negatives       2024.100000
# False Positives       221.900000
# False Negatives        32.300000
# True Positives         13.700000
# dtype: float64
# 28/29
# Balanced Accuracy       0.620427
# MCC                     0.116324
# Accuracy                0.898778
# F1-Score                0.116890
# Precision               0.071187
# Recall                  0.330435
# True Negatives       2044.800000
# False Positives       201.200000
# False Negatives        30.800000
# True Positives         15.200000
# dtype: float64
# 29/29
# Balanced Accuracy       0.665611
# MCC                     0.157223
# Accuracy                0.899695
# F1-Score                0.144904
# Precision               0.087625
# Recall                  0.421739
# True Negatives       2042.700000
# False Positives       203.300000
# False Negatives        26.600000
# True Positives         19.400000
# dtype: float64
# Standard 2
# 1/29
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Balanced Accuracy       0.541509
# MCC                     0.033461
# Accuracy                0.281991
# F1-Score                0.072567
# Precision               0.037976
# Recall                  0.820000
# True Negatives        857.700000
# False Positives      2403.300000
# False Negatives        20.700000
# True Positives         94.300000
# dtype: float64
# 2/29
# Balanced Accuracy       0.598297
# MCC                     0.075817
# Accuracy                0.669639
# F1-Score                0.097237
# Precision               0.053626
# Recall                  0.521739
# True Negatives       2200.700000
# False Positives      1060.300000
# False Negatives        55.000000
# True Positives         60.000000
# dtype: float64
# 3/29
# Balanced Accuracy       0.624119
# MCC                     0.092471
# Accuracy                0.621475
# F1-Score                0.101415
# Precision               0.055174
# Recall                  0.626957
# True Negatives       2026.000000
# False Positives      1235.000000
# False Negatives        42.900000
# True Positives         72.100000
# dtype: float64
# 4/29
# Balanced Accuracy       0.638728
# MCC                     0.108292
# Accuracy                0.691025
# F1-Score                0.113656
# Precision               0.062979
# Recall                  0.582609
# True Negatives       2265.900000
# False Positives       995.100000
# False Negatives        48.000000
# True Positives         67.000000
# dtype: float64
# 5/29
# Balanced Accuracy       0.664127
# MCC                     0.126225
# Accuracy                0.675267
# F1-Score                0.120431
# Precision               0.066354
# Recall                  0.652174
# True Negatives       2204.700000
# False Positives      1056.300000
# False Negatives        40.000000
# True Positives         75.000000
# dtype: float64
# 6/29
# Balanced Accuracy       0.654997
# MCC                     0.119215
# Accuracy                0.674645
# F1-Score                0.117210
# Precision               0.064582
# Recall                  0.633913
# True Negatives       2204.700000
# False Positives      1056.300000
# False Negatives        42.100000
# True Positives         72.900000
# dtype: float64
# 7/29
# Balanced Accuracy       0.671407
# MCC                     0.136035
# Accuracy                0.707968
# F1-Score                0.129130
# Precision               0.071953
# Recall                  0.632174
# True Negatives       2317.400000
# False Positives       943.600000
# False Negatives        42.300000
# True Positives         72.700000
# dtype: float64
# 8/29
# Balanced Accuracy       0.667812
# MCC                     0.135005
# Accuracy                0.718039
# F1-Score                0.130262
# Precision               0.072911
# Recall                  0.613913
# True Negatives       2353.500000
# False Positives       907.500000
# False Negatives        44.400000
# True Positives         70.600000
# dtype: float64
# 9/29
# Balanced Accuracy       0.670637
# MCC                     0.136461
# Accuracy                0.716203
# F1-Score                0.130287
# Precision               0.072799
# Recall                  0.621739
# True Negatives       2346.400000
# False Positives       914.600000
# False Negatives        43.500000
# True Positives         71.500000
# dtype: float64
# 10/29
# Balanced Accuracy       0.667726
# MCC                     0.134121
# Accuracy                0.717062
# F1-Score                0.129055
# Precision               0.072124
# Recall                  0.614783
# True Negatives       2350.100000
# False Positives       910.900000
# False Negatives        44.300000
# True Positives         70.700000
# dtype: float64
# 11/29
# Balanced Accuracy       0.625319
# MCC                     0.104183
# Accuracy                0.743720
# F1-Score                0.116920
# Precision               0.066281
# Recall                  0.498261
# True Negatives       2453.500000
# False Positives       807.500000
# False Negatives        57.700000
# True Positives         57.300000
# dtype: float64
# 12/29
# Balanced Accuracy       0.629863
# MCC                     0.107312
# Accuracy                0.740344
# F1-Score                0.118179
# Precision               0.066842
# Recall                  0.511304
# True Negatives       2440.600000
# False Positives       820.400000
# False Negatives        56.200000
# True Positives         58.800000
# dtype: float64
# 13/29
# Balanced Accuracy       0.627012
# MCC                     0.104385
# Accuracy                0.732405
# F1-Score                0.116223
# Precision               0.065572
# Recall                  0.513913
# True Negatives       2413.500000
# False Positives       847.500000
# False Negatives        55.900000
# True Positives         59.100000
# dtype: float64
# 14/29
# Balanced Accuracy       0.581511
# MCC                     0.067359
# Accuracy                0.734449
# F1-Score                0.096563
# Precision               0.054637
# Recall                  0.417391
# True Negatives       2431.500000
# False Positives       829.500000
# False Negatives        67.000000
# True Positives         48.000000
# dtype: float64
# 15/29
# Balanced Accuracy       0.635518
# MCC                     0.109655
# Accuracy                0.722097
# F1-Score                0.117682
# Precision               0.066043
# Recall                  0.542609
# True Negatives       2375.400000
# False Positives       885.600000
# False Negatives        52.600000
# True Positives         62.400000
# dtype: float64
# 16/29
# Balanced Accuracy       0.598724
# MCC                     0.080138
# Accuracy                0.720705
# F1-Score                0.102537
# Precision               0.057609
# Recall                  0.467826
# True Negatives       2379.300000
# False Positives       881.700000
# False Negatives        61.200000
# True Positives         53.800000
# dtype: float64
# 17/29
# Balanced Accuracy       0.614746
# MCC                     0.092731
# Accuracy                0.720053
# F1-Score                0.108848
# Precision               0.061048
# Recall                  0.501739
# True Negatives       2373.200000
# False Positives       887.800000
# False Negatives        57.300000
# True Positives         57.700000
# dtype: float64
# 18/29
# Balanced Accuracy       0.596527
# MCC                     0.077669
# Accuracy                0.714840
# F1-Score                0.100685
# Precision               0.056426
# Recall                  0.469565
# True Negatives       2359.300000
# False Positives       901.700000
# False Negatives        61.000000
# True Positives         54.000000
# dtype: float64
# 19/29
# Balanced Accuracy       0.583703
# MCC                     0.066830
# Accuracy                0.704650
# F1-Score                0.094819
# Precision               0.052960
# Recall                  0.453913
# True Negatives       2326.700000
# False Positives       934.300000
# False Negatives        62.800000
# True Positives         52.200000
# dtype: float64
# 20/29
# Balanced Accuracy       0.591478
# MCC                     0.073205
# Accuracy                0.705895
# F1-Score                0.098158
# Precision               0.054868
# Recall                  0.468696
# True Negatives       2329.200000
# False Positives       931.800000
# False Negatives        61.100000
# True Positives         53.900000
# dtype: float64
# 21/29
# Balanced Accuracy       0.590243
# MCC                     0.071270
# Accuracy                0.697838
# F1-Score                0.096420
# Precision               0.053679
# Recall                  0.474783
# True Negatives       2301.300000
# False Positives       959.700000
# False Negatives        60.400000
# True Positives         54.600000
# dtype: float64
# 22/29
# Balanced Accuracy       0.580888
# MCC                     0.063178
# Accuracy                0.684627
# F1-Score                0.091873
# Precision               0.050946
# Recall                  0.469565
# True Negatives       2257.300000
# False Positives      1003.700000
# False Negatives        61.000000
# True Positives         54.000000
# dtype: float64
# 23/29
# Balanced Accuracy       0.600103
# MCC                     0.078653
# Accuracy                0.691765
# F1-Score                0.099811
# Precision               0.055431
# Recall                  0.501739
# True Negatives       2277.700000
# False Positives       983.300000
# False Negatives        57.300000
# True Positives         57.700000
# dtype: float64
# 24/29
# Balanced Accuracy       0.600654
# MCC                     0.079621
# Accuracy                0.695261
# F1-Score                0.100755
# Precision               0.056061
# Recall                  0.499130
# True Negatives       2289.800000
# False Positives       971.200000
# False Negatives        57.600000
# True Positives         57.400000
# dtype: float64
# 25/29
# Balanced Accuracy       0.594980
# MCC                     0.075513
# Accuracy                0.698075
# F1-Score                0.098970
# Precision               0.055179
# Recall                  0.484348
# True Negatives       2301.000000
# False Positives       960.000000
# False Negatives        59.300000
# True Positives         55.700000
# dtype: float64
# 26/29
# Balanced Accuracy       0.594537
# MCC                     0.075228
# Accuracy                0.703703
# F1-Score                0.098828
# Precision               0.055156
# Recall                  0.477391
# True Negatives       2320.800000
# False Positives       940.200000
# False Negatives        60.100000
# True Positives         54.900000
# dtype: float64
# 27/29
# Balanced Accuracy       0.586298
# MCC                     0.068633
# Accuracy                0.699941
# F1-Score                0.095570
# Precision               0.053286
# Recall                  0.464348
# True Negatives       2309.600000
# False Positives       951.400000
# False Negatives        61.600000
# True Positives         53.400000
# dtype: float64
# 28/29
# Balanced Accuracy       0.588502
# MCC                     0.069445
# Accuracy                0.691232
# F1-Score                0.095125
# Precision               0.052849
# Recall                  0.478261
# True Negatives       2278.600000
# False Positives       982.400000
# False Negatives        60.000000
# True Positives         55.000000
# dtype: float64
# 29/29
# Balanced Accuracy       0.588022
# MCC                     0.070154
# Accuracy                0.700030
# F1-Score                0.096465
# Precision               0.053810
# Recall                  0.467826
# True Negatives       2309.500000
# False Positives       951.500000
# False Negatives        61.200000
# True Positives         53.800000
# dtype: float64

# %%
for key in set_dict.keys():
    bigg_df = pd.DataFrame()
    for i in set_dict[key]['Features']['Runs']['All runs'].keys():
        set_dict[key]['Features']['Runs']['All runs'][i].loc[:,'No. Features'] = i
        bigg_df =pd.concat([bigg_df,set_dict[key]['Features']['Runs']['All runs'][i]]).reset_index(drop=True)        
    set_dict[key]['Features']['All runs DF'] = bigg_df
    plt.tight_layout()
    ax= plot_boxchart(bigg_df,title=key)

# %%
key ='Standard 2'
from sklearn.decomposition import PCA

min_features = 10
max_features = 45
jump = 3

# for i in [1]:
for key in set_dict.keys():
    print(key)
    set_dict[key]['PCA reduction'] = {}
    set_dict[key]['PCA reduction']['Runs'] = {}
    set_dict[key]['PCA reduction']['Runs']['Scores'] = {}
    set_dict[key]['PCA reduction']['Runs']['All runs'] = {}
    filename = set_dict[key]['filename']
    df = read_data(filename,folder)
    
    Y = df.pop('Class')    
    df.loc[:,df.dtypes == 'bool'] = df.loc[:,df.dtypes == 'bool'].astype(int)
    
    no_feats=list(range(min_features,min(max_features,df.shape[1]-1),jump))
    for i,n_features in enumerate(no_feats):
        print('{}/{}'.format(i+1,len(no_feats)))
        
        Xtrain,Xtest,Ytrain,Ytest = sets = train_test_split(df,Y.values,
                        train_size=0.5,
                        shuffle=False)
        
        Xtrain,scaler = scale_data(Xtrain,'MinMax')
        Xtest= scaler.transform(Xtest.values)
        
        pca = PCA(n_components= n_features)
        Xtrain = pca.fit_transform(Xtrain)
        Xtest  = pca.transform(Xtest)
        
        mets = 0
        score_df = pd.DataFrame()
        for j in range(10):
            elm = ELM(m=128,w=10,type='wc') # 'standard 2'
            elm.fit(Xtrain,Ytrain)
            Ypreds = elm.predict(Xtest)
            met = getMetrics(Ytest,Ypreds)
            mets += met
            
            met.loc['Run'] = j+1
            score_df = score_df.append(met,ignore_index=True)
            
        print(mets/(j+1))
        set_dict[key]['PCA reduction']['Runs']['Scores'][n_features] = mets / (j+1)
        set_dict[key]['PCA reduction']['Runs']['All runs'][n_features] = score_df
# Out:
# Standard
# 1/5
# Balanced Accuracy       0.504132
# MCC                     0.012910
# Accuracy                0.971335
# F1-Score                0.023935
# Precision               0.040270
# Recall                  0.017391
# True Negatives       2225.500000
# False Positives        20.500000
# False Negatives        45.200000
# True Positives          0.800000
# dtype: float64
# 2/5
# Balanced Accuracy       0.500274
# MCC                     0.000597
# Accuracy                0.972120
# F1-Score                0.012024
# Precision               0.020488
# Recall                  0.008696
# True Negatives       2227.700000
# False Positives        18.300000
# False Negatives        45.600000
# True Positives          0.400000
# dtype: float64
# 3/5
# Balanced Accuracy       0.508172
# MCC                     0.025058
# Accuracy                0.972993
# F1-Score                0.033691
# Precision               0.057553
# Recall                  0.023913
# True Negatives       2229.000000
# False Positives        17.000000
# False Negatives        44.900000
# True Positives          1.100000
# dtype: float64
# 4/5
# Balanced Accuracy       0.506332
# MCC                     0.019961
# Accuracy                0.973560
# F1-Score                0.027877
# Precision               0.052222
# Recall                  0.019565
# True Negatives       2230.500000
# False Positives        15.500000
# False Negatives        45.100000
# True Positives          0.900000
# dtype: float64
# 5/5
# Balanced Accuracy       0.510613
# MCC                     0.035181
# Accuracy                0.973604
# F1-Score                0.041070
# Precision               0.078447
# Recall                  0.028261
# True Negatives       2230.200000
# False Positives        15.800000
# False Negatives        44.700000
# True Positives          1.300000
# dtype: float64
# Aggregated 1
# 1/7
# Balanced Accuracy       0.499432
# MCC                    -0.002154
# Accuracy                0.972557
# F1-Score                0.009034
# Precision               0.015809
# Recall                  0.006522
# True Negatives       2228.800000
# False Positives        17.200000
# False Negatives        45.700000
# True Positives          0.300000
# dtype: float64
# 2/7
# Balanced Accuracy       0.503071
# MCC                     0.009886
# Accuracy                0.973429
# F1-Score                0.018468
# Precision               0.037406
# Recall                  0.013043
# True Negatives       2230.500000
# False Positives        15.500000
# False Negatives        45.400000
# True Positives          0.600000
# dtype: float64
# 3/7
# Balanced Accuracy       0.526361
# MCC                     0.075455
# Accuracy                0.973168
# F1-Score                0.081503
# Precision               0.128178
# Recall                  0.060870
# True Negatives       2227.700000
# False Positives        18.300000
# False Negatives        43.200000
# True Positives          2.800000
# dtype: float64
# 4/7
# Balanced Accuracy       0.655705
# MCC                     0.342110
# Accuracy                0.976265
# F1-Score                0.351822
# Precision               0.390843
# Recall                  0.321739
# True Negatives       2222.800000
# False Positives        23.200000
# False Negatives        31.200000
# True Positives         14.800000
# dtype: float64
# 5/7
# Balanced Accuracy       0.624784
# MCC                     0.298095
# Accuracy                0.976178
# F1-Score                0.302927
# Precision               0.375018
# Recall                  0.258696
# True Negatives       2225.500000
# False Positives        20.500000
# False Negatives        34.100000
# True Positives         11.900000
# dtype: float64
# 6/7
# Balanced Accuracy       0.634455
# MCC                     0.314965
# Accuracy                0.976353
# F1-Score                0.320612
# Precision               0.387438
# Recall                  0.278261
# True Negatives       2225.000000
# False Positives        21.000000
# False Negatives        33.200000
# True Positives         12.800000
# dtype: float64
# 7/7
# Balanced Accuracy       0.645793
# MCC                     0.344526
# Accuracy                0.977705
# F1-Score                0.349449
# Precision               0.423333
# Recall                  0.300000
# True Negatives       2227.100000
# False Positives        18.900000
# False Negatives        32.200000
# True Positives         13.800000
# dtype: float64
# Aggregated 2
# 1/7
# Balanced Accuracy       0.500470
# MCC                     0.000793
# Accuracy                0.970419
# F1-Score                0.013984
# Precision               0.019718
# Recall                  0.010870
# True Negatives       2223.700000
# False Positives        22.300000
# False Negatives        45.500000
# True Positives          0.500000
# dtype: float64
# 2/7
# Balanced Accuracy       0.501869
# MCC                     0.004866
# Accuracy                0.971073
# F1-Score                0.017144
# Precision               0.026471
# Recall                  0.013043
# True Negatives       2225.100000
# False Positives        20.900000
# False Negatives        45.400000
# True Positives          0.600000
# dtype: float64
# 3/7
# Balanced Accuracy       0.515139
# MCC                     0.049474
# Accuracy                0.974127
# F1-Score                0.052405
# Precision               0.104861
# Recall                  0.036957
# True Negatives       2231.000000
# False Positives        15.000000
# False Negatives        44.300000
# True Positives          1.700000
# dtype: float64
# 4/7
# Balanced Accuracy       0.514097
# MCC                     0.046227
# Accuracy                0.974171
# F1-Score                0.050418
# Precision               0.096263
# Recall                  0.034783
# True Negatives       2231.200000
# False Positives        14.800000
# False Negatives        44.400000
# True Positives          1.600000
# dtype: float64
# 5/7
# Balanced Accuracy       0.506666
# MCC                     0.023699
# Accuracy                0.974215
# F1-Score                0.028919
# Precision               0.064764
# Recall                  0.019565
# True Negatives       2232.000000
# False Positives        14.000000
# False Negatives        45.100000
# True Positives          0.900000
# dtype: float64
# 6/7
# Balanced Accuracy       0.515584
# MCC                     0.059050
# Accuracy                0.975000
# F1-Score                0.056337
# Precision               0.135840
# Recall                  0.036957
# True Negatives       2233.000000
# False Positives        13.000000
# False Negatives        44.300000
# True Positives          1.700000
# dtype: float64
# 7/7
# Balanced Accuracy       0.507909
# MCC                     0.027789
# Accuracy                0.974564
# F1-Score                0.032256
# Precision               0.069921
# Recall                  0.021739
# True Negatives       2232.700000
# False Positives        13.300000
# False Negatives        45.000000
# True Positives          1.000000
# dtype: float64
# Aggregated 3
# 1/7
# Balanced Accuracy       0.506172
# MCC                     0.016643
# Accuracy                0.971161
# F1-Score                0.027960
# Precision               0.043685
# Recall                  0.021739
# True Negatives       2224.900000
# False Positives        21.100000
# False Negatives        45.000000
# True Positives          1.000000
# dtype: float64
# 2/7
# Balanced Accuracy       0.502756
# MCC                     0.009601
# Accuracy                0.970724
# F1-Score                0.021072
# Precision               0.036513
# Recall                  0.015217
# True Negatives       2224.200000
# False Positives        21.800000
# False Negatives        45.300000
# True Positives          0.700000
# dtype: float64
# 3/7
# Balanced Accuracy       0.510390
# MCC                     0.032564
# Accuracy                0.973168
# F1-Score                0.040066
# Precision               0.070853
# Recall                  0.028261
# True Negatives       2229.200000
# False Positives        16.800000
# False Negatives        44.700000
# True Positives          1.300000
# dtype: float64
# 4/7
# Balanced Accuracy       0.514961
# MCC                     0.046979
# Accuracy                0.973778
# F1-Score                0.052696
# Precision               0.093860
# Recall                  0.036957
# True Negatives       2230.200000
# False Positives        15.800000
# False Negatives        44.300000
# True Positives          1.700000
# dtype: float64
# 5/7
# Balanced Accuracy       0.502073
# MCC                     0.007616
# Accuracy                0.973560
# F1-Score                0.016160
# Precision               0.034539
# Recall                  0.010870
# True Negatives       2230.900000
# False Positives        15.100000
# False Negatives        45.500000
# True Positives          0.500000
# dtype: float64
# 6/7
# Balanced Accuracy       0.512787
# MCC                     0.042963
# Accuracy                0.973691
# F1-Score                0.046973
# Precision               0.095002
# Recall                  0.032609
# True Negatives       2230.200000
# False Positives        15.800000
# False Negatives        44.500000
# True Positives          1.500000
# dtype: float64
# 7/7
# Balanced Accuracy       0.508550
# MCC                     0.028278
# Accuracy                0.973735
# F1-Score                0.034586
# Precision               0.067934
# Recall                  0.023913
# True Negatives       2230.700000
# False Positives        15.300000
# False Negatives        44.900000
# True Positives          1.100000
# dtype: float64
# Aggregated 4
# 1/12
# Balanced Accuracy       0.502551
# MCC                     0.008812
# Accuracy                0.968237
# F1-Score                0.022498
# Precision               0.034592
# Recall                  0.017391
# True Negatives       2218.400000
# False Positives        27.600000
# False Negatives        45.200000
# True Positives          0.800000
# dtype: float64
# 2/12
# Balanced Accuracy       0.501487
# MCC                     0.003898
# Accuracy                0.968237
# F1-Score                0.018834
# Precision               0.024848
# Recall                  0.015217
# True Negatives       2218.500000
# False Positives        27.500000
# False Negatives        45.300000
# True Positives          0.700000
# dtype: float64
# 3/12
# Balanced Accuracy       0.510591
# MCC                     0.030291
# Accuracy                0.973560
# F1-Score                0.038536
# Precision               0.063223
# Recall                  0.028261
# True Negatives       2230.100000
# False Positives        15.900000
# False Negatives        44.700000
# True Positives          1.300000
# dtype: float64
# 4/12
# Balanced Accuracy       0.516270
# MCC                     0.050199
# Accuracy                0.974258
# F1-Score                0.055264
# Precision               0.097456
# Recall                  0.039130
# True Negatives       2231.200000
# False Positives        14.800000
# False Negatives        44.200000
# True Positives          1.800000
# dtype: float64
# 5/12
# Balanced Accuracy       0.544995
# MCC                     0.133668
# Accuracy                0.974215
# F1-Score                0.134037
# Precision               0.218772
# Recall                  0.097826
# True Negatives       2228.400000
# False Positives        17.600000
# False Negatives        41.500000
# True Positives          4.500000
# dtype: float64
# 6/12
# Balanced Accuracy       0.554715
# MCC                     0.170585
# Accuracy                0.976571
# F1-Score                0.162212
# Precision               0.289286
# Recall                  0.115217
# True Negatives       2233.000000
# False Positives        13.000000
# False Negatives        40.700000
# True Positives          5.300000
# dtype: float64
# 7/12
# Balanced Accuracy       0.548634
# MCC                     0.146222
# Accuracy                0.975087
# F1-Score                0.144139
# Precision               0.240334
# Recall                  0.104348
# True Negatives       2230.100000
# False Positives        15.900000
# False Negatives        41.200000
# True Positives          4.800000
# dtype: float64
# 8/12
# Balanced Accuracy       0.552247
# MCC                     0.143973
# Accuracy                0.973822
# F1-Score                0.146790
# Precision               0.220030
# Recall                  0.113043
# True Negatives       2226.800000
# False Positives        19.200000
# False Negatives        40.800000
# True Positives          5.200000
# dtype: float64
# 9/12
# Balanced Accuracy       0.560524
# MCC                     0.172696
# Accuracy                0.975436
# F1-Score                0.170984
# Precision               0.267669
# Recall                  0.128261
# True Negatives       2229.800000
# False Positives        16.200000
# False Negatives        40.100000
# True Positives          5.900000
# dtype: float64
# 10/12
# Balanced Accuracy       0.556083
# MCC                     0.145764
# Accuracy                0.972993
# F1-Score                0.152737
# Precision               0.208566
# Recall                  0.121739
# True Negatives       2224.500000
# False Positives        21.500000
# False Negatives        40.400000
# True Positives          5.600000
# dtype: float64
# 11/12
# Balanced Accuracy       0.561188
# MCC                     0.171357
# Accuracy                0.974651
# F1-Score                0.171389
# Precision               0.261973
# Recall                  0.130435
# True Negatives       2227.900000
# False Positives        18.100000
# False Negatives        40.000000
# True Positives          6.000000
# dtype: float64
# 12/12
# Balanced Accuracy       0.555263
# MCC                     0.152038
# Accuracy                0.973473
# F1-Score                0.154940
# Precision               0.230983
# Recall                  0.119565
# True Negatives       2225.700000
# False Positives        20.300000
# False Negatives        40.500000
# True Positives          5.500000
# dtype: float64
# Aggregated 1+2
# 1/9
# Balanced Accuracy       0.499476
# MCC                    -0.001070
# Accuracy                0.972644
# F1-Score                0.009338
# Precision               0.020500
# Recall                  0.006522
# True Negatives       2229.000000
# False Positives        17.000000
# False Negatives        45.700000
# True Positives          0.300000
# dtype: float64
# 2/9
# Balanced Accuracy       0.502934
# MCC                     0.008721
# Accuracy                0.971073
# F1-Score                0.020618
# Precision               0.033003
# Recall                  0.015217
# True Negatives       2225.000000
# False Positives        21.000000
# False Negatives        45.300000
# True Positives          0.700000
# dtype: float64
# 3/9
# Balanced Accuracy       0.530842
# MCC                     0.087444
# Accuracy                0.973604
# F1-Score                0.092176
# Precision               0.145447
# Recall                  0.069565
# True Negatives       2228.300000
# False Positives        17.700000
# False Negatives        42.800000
# True Positives          3.200000
# dtype: float64
# 4/9
# Balanced Accuracy       0.517955
# MCC                     0.053101
# Accuracy                0.973386
# F1-Score                0.059392
# Precision               0.099045
# Recall                  0.043478
# True Negatives       2229.000000
# False Positives        17.000000
# False Negatives        44.000000
# True Positives          2.000000
# dtype: float64
# 5/9
# Balanced Accuracy       0.653887
# MCC                     0.346169
# Accuracy                0.976876
# F1-Score                0.353958
# Precision               0.405723
# Recall                  0.317391
# True Negatives       2224.400000
# False Positives        21.600000
# False Negatives        31.400000
# True Positives         14.600000
# dtype: float64
# 6/9
# Balanced Accuracy       0.651045
# MCC                     0.328639
# Accuracy                0.975480
# F1-Score                0.338137
# Precision               0.374563
# Recall                  0.313043
# True Negatives       2221.400000
# False Positives        24.600000
# False Negatives        31.600000
# True Positives         14.400000
# dtype: float64
# 7/9
# Balanced Accuracy       0.654021
# MCC                     0.350661
# Accuracy                0.977138
# F1-Score                0.356857
# Precision               0.417092
# Recall                  0.317391
# True Negatives       2225.000000
# False Positives        21.000000
# False Negatives        31.400000
# True Positives         14.600000
# dtype: float64
# 8/9
# Balanced Accuracy       0.637409
# MCC                     0.337076
# Accuracy                0.977967
# F1-Score                0.339090
# Precision               0.430862
# Recall                  0.282609
# True Negatives       2228.500000
# False Positives        17.500000
# False Negatives        33.000000
# True Positives         13.000000
# dtype: float64
# 9/9
# Balanced Accuracy       0.654440
# MCC                     0.337024
# Accuracy                0.975873
# F1-Score                0.347357
# Precision               0.382504
# Recall                  0.319565
# True Negatives       2222.000000
# False Positives        24.000000
# False Negatives        31.300000
# True Positives         14.700000
# dtype: float64
# Aggregated 1+2+4
# 1/12
# Balanced Accuracy       0.500511
# MCC                     0.001104
# Accuracy                0.968412
# F1-Score                0.015842
# Precision               0.020867
# Recall                  0.013043
# True Negatives       2219.000000
# False Positives        27.000000
# False Negatives        45.400000
# True Positives          0.600000
# dtype: float64
# 2/12
# Balanced Accuracy       0.501539
# MCC                     0.006869
# Accuracy                0.972513
# F1-Score                0.016340
# Precision               0.034771
# Recall                  0.010870
# True Negatives       2228.500000
# False Positives        17.500000
# False Negatives        45.500000
# True Positives          0.500000
# dtype: float64
# 3/12
# Balanced Accuracy       0.503668
# MCC                     0.015836
# Accuracy                0.972513
# F1-Score                0.023140
# Precision               0.053644
# Recall                  0.015217
# True Negatives       2228.300000
# False Positives        17.700000
# False Negatives        45.300000
# True Positives          0.700000
# dtype: float64
# 4/12
# Balanced Accuracy       0.576806
# MCC                     0.212408
# Accuracy                0.976047
# F1-Score                0.208442
# Precision               0.320089
# Recall                  0.160870
# True Negatives       2229.700000
# False Positives        16.300000
# False Negatives        38.600000
# True Positives          7.400000
# dtype: float64
# 5/12
# Balanced Accuracy       0.636919
# MCC                     0.325409
# Accuracy                0.977007
# F1-Score                0.330905
# Precision               0.402745
# Recall                  0.282609
# True Negatives       2226.300000
# False Positives        19.700000
# False Negatives        33.000000
# True Positives         13.000000
# dtype: float64
# 6/12
# Balanced Accuracy       0.653531
# MCC                     0.336519
# Accuracy                0.976178
# F1-Score                0.345896
# Precision               0.384779
# Recall                  0.317391
# True Negatives       2222.800000
# False Positives        23.200000
# False Negatives        31.400000
# True Positives         14.600000
# dtype: float64
# 7/12
# Balanced Accuracy       0.619657
# MCC                     0.270086
# Accuracy                0.974476
# F1-Score                0.279836
# Precision               0.321777
# Recall                  0.250000
# True Negatives       2222.000000
# False Positives        24.000000
# False Negatives        34.500000
# True Positives         11.500000
# dtype: float64
# 8/12
# Balanced Accuracy       0.630972
# MCC                     0.303348
# Accuracy                0.975785
# F1-Score                0.308916
# Precision               0.372420
# Recall                  0.271739
# True Negatives       2224.000000
# False Positives        22.000000
# False Negatives        33.500000
# True Positives         12.500000
# dtype: float64
# 9/12
# Balanced Accuracy       0.639289
# MCC                     0.308136
# Accuracy                0.975393
# F1-Score                0.317516
# Precision               0.357757
# Recall                  0.289130
# True Negatives       2222.300000
# False Positives        23.700000
# False Negatives        32.700000
# True Positives         13.300000
# dtype: float64
# 10/12
# Balanced Accuracy       0.640398
# MCC                     0.317291
# Accuracy                0.975480
# F1-Score                0.323844
# Precision               0.379358
# Recall                  0.291304
# True Negatives       2222.400000
# False Positives        23.600000
# False Negatives        32.600000
# True Positives         13.400000
# dtype: float64
# 11/12
# Balanced Accuracy       0.629217
# MCC                     0.289055
# Accuracy                0.974433
# F1-Score                0.298778
# Precision               0.340375
# Recall                  0.269565
# True Negatives       2221.000000
# False Positives        25.000000
# False Negatives        33.600000
# True Positives         12.400000
# dtype: float64
# 12/12
# Balanced Accuracy       0.626735
# MCC                     0.295981
# Accuracy                0.975829
# F1-Score                0.303200
# Precision               0.362569
# Recall                  0.263043
# True Negatives       2224.500000
# False Positives        21.500000
# False Negatives        33.900000
# True Positives         12.100000
# dtype: float64
# Aggregated 1+2+3+4
# 1/12
# Balanced Accuracy       0.500355
# MCC                     0.000296
# Accuracy                0.968106
# F1-Score                0.015411
# Precision               0.019312
# Recall                  0.013043
# True Negatives       2218.300000
# False Positives        27.700000
# False Negatives        45.400000
# True Positives          0.600000
# dtype: float64
# 2/12
# Balanced Accuracy       0.500070
# MCC                     0.000136
# Accuracy                0.969634
# F1-Score                0.014026
# Precision               0.019899
# Recall                  0.010870
# True Negatives       2221.900000
# False Positives        24.100000
# False Negatives        45.500000
# True Positives          0.500000
# dtype: float64
# 3/12
# Balanced Accuracy       0.504114
# MCC                     0.012726
# Accuracy                0.973386
# F1-Score                0.021192
# Precision               0.041716
# Recall                  0.015217
# True Negatives       2230.300000
# False Positives        15.700000
# False Negatives        45.300000
# True Positives          0.700000
# dtype: float64
# 4/12
# Balanced Accuracy       0.540651
# MCC                     0.134750
# Accuracy                0.976134
# F1-Score                0.127224
# Precision               0.244116
# Recall                  0.086957
# True Negatives       2233.300000
# False Positives        12.700000
# False Negatives        42.000000
# True Positives          4.000000
# dtype: float64
# 5/12
# Balanced Accuracy       0.537501
# MCC                     0.120647
# Accuracy                0.976222
# F1-Score                0.113388
# Precision               0.224135
# Recall                  0.080435
# True Negatives       2233.800000
# False Positives        12.200000
# False Negatives        42.300000
# True Positives          3.700000
# dtype: float64
# 6/12
# Balanced Accuracy       0.648627
# MCC                     0.319820
# Accuracy                0.974913
# F1-Score                0.330856
# Precision               0.359575
# Recall                  0.308696
# True Negatives       2220.300000
# False Positives        25.700000
# False Negatives        31.800000
# True Positives         14.200000
# dtype: float64
# 7/12
# Balanced Accuracy       0.634300
# MCC                     0.307535
# Accuracy                0.976047
# F1-Score                0.315159
# Precision               0.369240
# Recall                  0.278261
# True Negatives       2224.300000
# False Positives        21.700000
# False Negatives        33.200000
# True Positives         12.800000
# dtype: float64
# 8/12
# Balanced Accuracy       0.634211
# MCC                     0.309056
# Accuracy                0.975873
# F1-Score                0.315296
# Precision               0.375575
# Recall                  0.278261
# True Negatives       2223.900000
# False Positives        22.100000
# False Negatives        33.200000
# True Positives         12.800000
# dtype: float64
# 9/12
# Balanced Accuracy       0.627069
# MCC                     0.303149
# Accuracy                0.976483
# F1-Score                0.309297
# Precision               0.377481
# Recall                  0.263043
# True Negatives       2226.000000
# False Positives        20.000000
# False Negatives        33.900000
# True Positives         12.100000
# dtype: float64
# 10/12
# Balanced Accuracy       0.628464
# MCC                     0.293887
# Accuracy                0.975044
# F1-Score                0.301816
# Precision               0.354403
# Recall                  0.267391
# True Negatives       2222.500000
# False Positives        23.500000
# False Negatives        33.700000
# True Positives         12.300000
# dtype: float64
# 11/12
# Balanced Accuracy       0.634786
# MCC                     0.297680
# Accuracy                0.974913
# F1-Score                0.307449
# Precision               0.345707
# Recall                  0.280435
# True Negatives       2221.600000
# False Positives        24.400000
# False Negatives        33.100000
# True Positives         12.900000
# dtype: float64
# 12/12
# Balanced Accuracy       0.621390
# MCC                     0.287149
# Accuracy                0.975785
# F1-Score                0.290920
# Precision               0.362524
# Recall                  0.252174
# True Negatives       2224.900000
# False Positives        21.100000
# False Negatives        34.400000
# True Positives         11.600000
# dtype: float64
# Standard 2
# 1/10
# Balanced Accuracy       0.498519
# MCC                    -0.003717
# Accuracy                0.937145
# F1-Score                0.028629
# Precision               0.029598
# Recall                  0.027826
# True Negatives       3160.600000
# False Positives       100.400000
# False Negatives       111.800000
# True Positives          3.200000
# dtype: float64
# 2/10
# Balanced Accuracy       0.513599
# MCC                     0.026838
# Accuracy                0.935486
# F1-Score                0.059973
# Precision               0.059707
# Recall                  0.060870
# True Negatives       3151.200000
# False Positives       109.800000
# False Negatives       108.000000
# True Positives          7.000000
# dtype: float64
# 3/10
# Balanced Accuracy       0.510679
# MCC                     0.020856
# Accuracy                0.935515
# F1-Score                0.054074
# Precision               0.053753
# Recall                  0.054783
# True Negatives       3152.000000
# False Positives       109.000000
# False Negatives       108.700000
# True Positives          6.300000
# dtype: float64
# 4/10
# Balanced Accuracy       0.519051
# MCC                     0.040165
# Accuracy                0.937915
# F1-Score                0.071879
# Precision               0.075423
# Recall                  0.069565
# True Negatives       3158.400000
# False Positives       102.600000
# False Negatives       107.000000
# True Positives          8.000000
# dtype: float64
# 5/10
# Balanced Accuracy       0.527091
# MCC                     0.057082
# Accuracy                0.941291
# F1-Score                0.087083
# Precision               0.092489
# Recall                  0.082609
# True Negatives       3168.300000
# False Positives        92.700000
# False Negatives       105.500000
# True Positives          9.500000
# dtype: float64
# 6/10
# Balanced Accuracy       0.520947
# MCC                     0.046115
# Accuracy                0.942387
# F1-Score                0.075199
# Precision               0.083509
# Recall                  0.068696
# True Negatives       3173.600000
# False Positives        87.400000
# False Negatives       107.100000
# True Positives          7.900000
# dtype: float64
# 7/10
# Balanced Accuracy       0.525990
# MCC                     0.057973
# Accuracy                0.943217
# F1-Score                0.086407
# Precision               0.097159
# Recall                  0.078261
# True Negatives       3175.300000
# False Positives        85.700000
# False Negatives       106.000000
# True Positives          9.000000
# dtype: float64
# 8/10
# Balanced Accuracy       0.525812
# MCC                     0.055286
# Accuracy                0.942062
# F1-Score                0.084773
# Precision               0.091618
# Recall                  0.079130
# True Negatives       3171.300000
# False Positives        89.700000
# False Negatives       105.900000
# True Positives          9.100000
# dtype: float64
# 9/10
# Balanced Accuracy       0.519884
# MCC                     0.043274
# Accuracy                0.941143
# F1-Score                0.073195
# Precision               0.079922
# Recall                  0.067826
# True Negatives       3169.500000
# False Positives        91.500000
# False Negatives       107.200000
# True Positives          7.800000
# dtype: float64
# 10/10
# Balanced Accuracy       0.526708
# MCC                     0.055273
# Accuracy                0.940551
# F1-Score                0.085637
# Precision               0.089666
# Recall                  0.082609
# True Negatives       3165.800000
# False Positives        95.200000
# False Negatives       105.500000
# True Positives          9.500000
# dtype: float64

# %%
for key in set_dict.keys():
    bigg_df = pd.DataFrame()
    for i in set_dict[key]['PCA reduction']['Runs']['All runs'].keys():
        set_dict[key]['PCA reduction']['Runs']['All runs'][i].loc[:,'No. PCA components'] = i
        bigg_df =pd.concat([bigg_df,set_dict[key]['PCA reduction']['Runs']['All runs'][i]]).reset_index(drop=True)        
    set_dict[key]['PCA reduction']['All runs DF'] = bigg_df
    plt.tight_layout()
    ax= plot_boxchart(bigg_df,title=key,x='No. PCA components',xlabel='No. PCA components')

# %% [markdown]
# ## Feature selection and PCA reduction

# %%
key ='Standard 2'
from sklearn.decomposition import PCA

min_features = 15
max_features = 45
jump = 5

# for i in [1]:
for key in set_dict.keys():
    print(key)
    set_dict[key]['PCA n Features'] = {}
    set_dict[key]['PCA n Features']['Runs'] = {}
    set_dict[key]['PCA n Features']['Runs']['Scores'] = {}
    set_dict[key]['PCA n Features']['Runs']['All runs'] = {}
    
    feature_order = set_dict[key]['Features']['Importance Order']
    
    filename = set_dict[key]['filename']
    df = read_data(filename,folder)
    
    Y = df.pop('Class')    
    df.loc[:,df.dtypes == 'bool'] = df.loc[:,df.dtypes == 'bool'].astype(int)
    
    no_feats=list(range(min_features,min(max_features,df.shape[1]-1),jump))
    for i,n_features in enumerate(no_feats):
        print('{}/{}'.format(i+1,len(no_feats)))
        
        set_dict[key]['PCA n Features']['Runs']['Scores'][n_features] = {}
        set_dict[key]['PCA n Features']['Runs']['All runs'][n_features] = {}
        score_df = pd.DataFrame()
        for i,n_pca_reduction in enumerate([-3,-6,-9,-12]):
            print(n_pca_reduction)
            n_components = n_features + n_pca_reduction
        
            Xtrain,Xtest,Ytrain,Ytest = sets = train_test_split(df,Y.values,
                            train_size=0.5,
                            shuffle=False)

            Xtrain,scaler = scale_data(Xtrain,'MinMax')
            Xtest= scaler.transform(Xtest.values)

            pca = PCA(n_components= n_components)
            Xtrain = pca.fit_transform(Xtrain)
            Xtest  = pca.transform(Xtest)
        
            mets = 0
            
            temp = pd.DataFrame()
            for j in range(10):
                elm = ELM(m=128,w=10,type='wc') # 'standard 2'
                elm.fit(Xtrain,Ytrain)
                Ypreds = elm.predict(Xtest)
                met = getMetrics(Ytest,Ypreds)
                mets += met

                met.loc['Run'] = j+1
                temp = temp.append(met,ignore_index=True)
            temp.loc[:,'PCA reduction'] = n_pca_reduction
            score_df = score_df.append(temp,ignore_index=True)
            
            print(mets/(j+1))
            
            set_dict[key]['PCA n Features']['Runs']['Scores'][n_features][n_pca_reduction] = mets / (j+1)
            set_dict[key]['PCA n Features']['Runs']['All runs'][n_features][n_pca_reduction] = score_df
# Out:
# Standard
# 1/2
# -3
# Balanced Accuracy       0.504800
# MCC                     0.014344
# Accuracy                0.972644
# F1-Score                0.023611
# Precision               0.043013
# Recall                  0.017391
# True Negatives       2228.500000
# False Positives        17.500000
# False Negatives        45.200000
# True Positives          0.800000
# dtype: float64
# -6
# Balanced Accuracy       0.504837
# MCC                     0.012127
# Accuracy                0.968543
# F1-Score                0.026422
# Precision               0.035423
# Recall                  0.021739
# True Negatives       2218.900000
# False Positives        27.100000
# False Negatives        45.000000
# True Positives          1.000000
# dtype: float64
# -9
# Balanced Accuracy       0.499673
# MCC                    -0.001376
# Accuracy                0.970942
# F1-Score                0.011473
# Precision               0.016890
# Recall                  0.008696
# True Negatives       2225.000000
# False Positives        21.000000
# False Negatives        45.600000
# True Positives          0.400000
# dtype: float64
# -12
# Balanced Accuracy       0.498032
# MCC                    -0.004152
# Accuracy                0.959380
# F1-Score                0.016515
# Precision               0.015759
# Recall                  0.017391
# True Negatives       2198.100000
# False Positives        47.900000
# False Negatives        45.200000
# True Positives          0.800000
# dtype: float64
# 2/2
# -3
# Balanced Accuracy       0.508350
# MCC                     0.023474
# Accuracy                0.973342
# F1-Score                0.032269
# Precision               0.053289
# Recall                  0.023913
# True Negatives       2229.800000
# False Positives        16.200000
# False Negatives        44.900000
# True Positives          1.100000
# dtype: float64
# -6
# Balanced Accuracy       0.500675
# MCC                     0.001660
# Accuracy                0.972906
# F1-Score                0.012250
# Precision               0.021702
# Recall                  0.008696
# True Negatives       2229.500000
# False Positives        16.500000
# False Negatives        45.600000
# True Positives          0.400000
# dtype: float64
# -9
# Balanced Accuracy       0.503423
# MCC                     0.009791
# Accuracy                0.972033
# F1-Score                0.020549
# Precision               0.033990
# Recall                  0.015217
# True Negatives       2227.200000
# False Positives        18.800000
# False Negatives        45.300000
# True Positives          0.700000
# dtype: float64
# -12
# Balanced Accuracy       0.496961
# MCC                    -0.006272
# Accuracy                0.967714
# F1-Score                0.008473
# Precision               0.014436
# Recall                  0.006522
# True Negatives       2217.700000
# False Positives        28.300000
# False Negatives        45.700000
# True Positives          0.300000
# dtype: float64
# Aggregated 1
# 1/3
# -3
# Balanced Accuracy       0.502381
# MCC                     0.006911
# Accuracy                0.972077
# F1-Score                0.017717
# Precision               0.030716
# Recall                  0.013043
# True Negatives       2227.400000
# False Positives        18.600000
# False Negatives        45.400000
# True Positives          0.600000
# dtype: float64
# -6
# Balanced Accuracy       0.503041
# MCC                     0.007143
# Accuracy                0.969197
# F1-Score                0.020835
# Precision               0.029221
# Recall                  0.017391
# True Negatives       2220.600000
# False Positives        25.400000
# False Negatives        45.200000
# True Positives          0.800000
# dtype: float64
# -9
# Balanced Accuracy       0.501936
# MCC                     0.004324
# Accuracy                0.971204
# F1-Score                0.016766
# Precision               0.024201
# Recall                  0.013043
# True Negatives       2225.400000
# False Positives        20.600000
# False Negatives        45.400000
# True Positives          0.600000
# dtype: float64
# -12
# Balanced Accuracy       0.495502
# MCC                    -0.008310
# Accuracy                0.958595
# F1-Score                0.012747
# Precision               0.012559
# Recall                  0.013043
# True Negatives       2196.500000
# False Positives        49.500000
# False Negatives        45.400000
# True Positives          0.600000
# dtype: float64
# 2/3
# -3
# Balanced Accuracy       0.529559
# MCC                     0.090816
# Accuracy                0.975262
# F1-Score                0.091631
# Precision               0.160115
# Recall                  0.065217
# True Negatives       2232.300000
# False Positives        13.700000
# False Negatives        43.000000
# True Positives          3.000000
# dtype: float64
# -6
# Balanced Accuracy       0.500648
# MCC                     0.003727
# Accuracy                0.970768
# F1-Score                0.015336
# Precision               0.028382
# Recall                  0.010870
# True Negatives       2224.500000
# False Positives        21.500000
# False Negatives        45.500000
# True Positives          0.500000
# dtype: float64
# -9
# Balanced Accuracy       0.502511
# MCC                     0.005096
# Accuracy                0.970244
# F1-Score                0.018328
# Precision               0.024700
# Recall                  0.015217
# True Negatives       2223.100000
# False Positives        22.900000
# False Negatives        45.300000
# True Positives          0.700000
# dtype: float64
# -12
# Balanced Accuracy       0.499472
# MCC                    -0.000040
# Accuracy                0.970550
# F1-Score                0.012422
# Precision               0.022024
# Recall                  0.008696
# True Negatives       2224.100000
# False Positives        21.900000
# False Negatives        45.600000
# True Positives          0.400000
# dtype: float64
# 3/3
# -3
# Balanced Accuracy       0.648386
# MCC                     0.336482
# Accuracy                0.976527
# F1-Score                0.344116
# Precision               0.398123
# Recall                  0.306522
# True Negatives       2224.100000
# False Positives        21.900000
# False Negatives        31.900000
# True Positives         14.100000
# dtype: float64
# -6
# Balanced Accuracy       0.638492
# MCC                     0.311428
# Accuracy                0.975916
# F1-Score                0.320442
# Precision               0.366072
# Recall                  0.286957
# True Negatives       2223.600000
# False Positives        22.400000
# False Negatives        32.800000
# True Positives         13.200000
# dtype: float64
# -9
# Balanced Accuracy       0.518489
# MCC                     0.057602
# Accuracy                0.974433
# F1-Score                0.061985
# Precision               0.108929
# Recall                  0.043478
# True Negatives       2231.400000
# False Positives        14.600000
# False Negatives        44.000000
# True Positives          2.000000
# dtype: float64
# -12
# Balanced Accuracy       0.504867
# MCC                     0.014806
# Accuracy                0.972775
# F1-Score                0.024400
# Precision               0.042884
# Recall                  0.017391
# True Negatives       2228.800000
# False Positives        17.200000
# False Negatives        45.200000
# True Positives          0.800000
# dtype: float64
# Aggregated 2
# 1/3
# -3
# Balanced Accuracy       0.499183
# MCC                    -0.002767
# Accuracy                0.969983
# F1-Score                0.010827
# Precision               0.015497
# Recall                  0.008696
# True Negatives       2222.800000
# False Positives        23.200000
# False Negatives        45.600000
# True Positives          0.400000
# dtype: float64
# -6
# Balanced Accuracy       0.502752
# MCC                     0.007609
# Accuracy                0.968630
# F1-Score                0.021870
# Precision               0.030688
# Recall                  0.017391
# True Negatives       2219.300000
# False Positives        26.700000
# False Negatives        45.200000
# True Positives          0.800000
# dtype: float64
# -9
# Balanced Accuracy       0.505326
# MCC                     0.014576
# Accuracy                0.969503
# F1-Score                0.027747
# Precision               0.040195
# Recall                  0.021739
# True Negatives       2221.100000
# False Positives        24.900000
# False Negatives        45.000000
# True Positives          1.000000
# dtype: float64
# -12
# Balanced Accuracy       0.490583
# MCC                    -0.019543
# Accuracy                0.961475
# F1-Score                0.000000
# Precision               0.000000
# Recall                  0.000000
# True Negatives       2203.700000
# False Positives        42.300000
# False Negatives        46.000000
# True Positives          0.000000
# dtype: float64
# 2/3
# -3
# Balanced Accuracy       0.511945
# MCC                     0.035332
# Accuracy                0.974127
# F1-Score                0.042631
# Precision               0.071438
# Recall                  0.030435
# True Negatives       2231.300000
# False Positives        14.700000
# False Negatives        44.600000
# True Positives          1.400000
# dtype: float64
# -6
# Balanced Accuracy       0.502893
# MCC                     0.008501
# Accuracy                0.973080
# F1-Score                0.018368
# Precision               0.032313
# Recall                  0.013043
# True Negatives       2229.700000
# False Positives        16.300000
# False Negatives        45.400000
# True Positives          0.600000
# dtype: float64
# -9
# Balanced Accuracy       0.503134
# MCC                     0.010235
# Accuracy                0.971466
# F1-Score                0.021361
# Precision               0.036526
# Recall                  0.015217
# True Negatives       2225.900000
# False Positives        20.100000
# False Negatives        45.300000
# True Positives          0.700000
# dtype: float64
# -12
# Balanced Accuracy       0.506057
# MCC                     0.013284
# Accuracy                0.968848
# F1-Score                0.027781
# Precision               0.034183
# Recall                  0.023913
# True Negatives       2219.500000
# False Positives        26.500000
# False Negatives        44.900000
# True Positives          1.100000
# dtype: float64
# 3/3
# -3
# Balanced Accuracy       0.508350
# MCC                     0.023703
# Accuracy                0.973342
# F1-Score                0.032535
# Precision               0.053429
# Recall                  0.023913
# True Negatives       2229.800000
# False Positives        16.200000
# False Negatives        44.900000
# True Positives          1.100000
# dtype: float64
# -6
# Balanced Accuracy       0.515937
# MCC                     0.053439
# Accuracy                0.973604
# F1-Score                0.054550
# Precision               0.123755
# Recall                  0.039130
# True Negatives       2229.700000
# False Positives        16.300000
# False Negatives        44.200000
# True Positives          1.800000
# dtype: float64
# -9
# Balanced Accuracy       0.512917
# MCC                     0.030872
# Accuracy                0.971859
# F1-Score                0.042618
# Precision               0.055134
# Recall                  0.034783
# True Negatives       2225.900000
# False Positives        20.100000
# False Negatives        44.400000
# True Positives          1.600000
# dtype: float64
# -12
# Balanced Accuracy       0.502693
# MCC                     0.008505
# Accuracy                0.972688
# F1-Score                0.018489
# Precision               0.033706
# Recall                  0.013043
# True Negatives       2228.800000
# False Positives        17.200000
# False Negatives        45.400000
# True Positives          0.600000
# dtype: float64
# Aggregated 3
# 1/3
# -3
# Balanced Accuracy       0.505504
# MCC                     0.013109
# Accuracy                0.969852
# F1-Score                0.026563
# Precision               0.035327
# Recall                  0.021739
# True Negatives       2221.900000
# False Positives        24.100000
# False Negatives        45.000000
# True Positives          1.000000
# dtype: float64
# -6
# Balanced Accuracy       0.494943
# MCC                    -0.012862
# Accuracy                0.967932
# F1-Score                0.002740
# Precision               0.003704
# Recall                  0.002174
# True Negatives       2218.400000
# False Positives        27.600000
# False Negatives        45.900000
# True Positives          0.100000
# dtype: float64
# -9
# Balanced Accuracy       0.508342
# MCC                     0.020931
# Accuracy                0.969154
# F1-Score                0.034804
# Precision               0.046197
# Recall                  0.028261
# True Negatives       2220.000000
# False Positives        26.000000
# False Negatives        44.700000
# True Positives          1.300000
# dtype: float64
# -12
# Balanced Accuracy       0.494267
# MCC                    -0.012331
# Accuracy                0.962435
# F1-Score                0.006725
# Precision               0.006960
# Recall                  0.006522
# True Negatives       2205.600000
# False Positives        40.400000
# False Negatives        45.700000
# True Positives          0.300000
# dtype: float64
# 2/3
# -3
# Balanced Accuracy       0.507664
# MCC                     0.029569
# Accuracy                0.974084
# F1-Score                0.033614
# Precision               0.076503
# Recall                  0.021739
# True Negatives       2231.600000
# False Positives        14.400000
# False Negatives        45.000000
# True Positives          1.000000
# dtype: float64
# -6
# Balanced Accuracy       0.506777
# MCC                     0.025435
# Accuracy                0.974433
# F1-Score                0.030014
# Precision               0.068295
# Recall                  0.019565
# True Negatives       2232.500000
# False Positives        13.500000
# False Negatives        45.100000
# True Positives          0.900000
# dtype: float64
# -9
# Balanced Accuracy       0.499892
# MCC                    -0.000593
# Accuracy                0.969284
# F1-Score                0.013391
# Precision               0.018649
# Recall                  0.010870
# True Negatives       2221.100000
# False Positives        24.900000
# False Negatives        45.500000
# True Positives          0.500000
# dtype: float64
# -12
# Balanced Accuracy       0.497410
# MCC                    -0.008282
# Accuracy                0.970681
# F1-Score                0.005112
# Precision               0.006274
# Recall                  0.004348
# True Negatives       2224.600000
# False Positives        21.400000
# False Negatives        45.800000
# True Positives          0.200000
# dtype: float64
# 3/3
# -3
# Balanced Accuracy       0.509504
# MCC                     0.030883
# Accuracy                0.973517
# F1-Score                0.037406
# Precision               0.070884
# Recall                  0.026087
# True Negatives       2230.100000
# False Positives        15.900000
# False Negatives        44.800000
# True Positives          1.200000
# dtype: float64
# -6
# Balanced Accuracy       0.518200
# MCC                     0.057299
# Accuracy                0.973866
# F1-Score                0.059814
# Precision               0.116101
# Recall                  0.043478
# True Negatives       2230.100000
# False Positives        15.900000
# False Negatives        44.000000
# True Positives          2.000000
# dtype: float64
# -9
# Balanced Accuracy       0.497833
# MCC                    -0.005911
# Accuracy                0.971510
# F1-Score                0.006300
# Precision               0.011438
# Recall                  0.004348
# True Negatives       2226.500000
# False Positives        19.500000
# False Negatives        45.800000
# True Positives          0.200000
# dtype: float64
# -12
# Balanced Accuracy       0.501713
# MCC                     0.004053
# Accuracy                0.970768
# F1-Score                0.016797
# Precision               0.024198
# Recall                  0.013043
# True Negatives       2224.400000
# False Positives        21.600000
# False Negatives        45.400000
# True Positives          0.600000
# dtype: float64
# Aggregated 4
# 1/6
# -3
# Balanced Accuracy       0.502885
# MCC                     0.009049
# Accuracy                0.968892
# F1-Score                0.022033
# Precision               0.035441
# Recall                  0.017391
# True Negatives       2219.900000
# False Positives        26.100000
# False Negatives        45.200000
# True Positives          0.800000
# dtype: float64
# -6
# Balanced Accuracy       0.507478
# MCC                     0.019751
# Accuracy                0.969546
# F1-Score                0.032885
# Precision               0.045638
# Recall                  0.026087
# True Negatives       2221.000000
# False Positives        25.000000
# False Negatives        44.800000
# True Positives          1.200000
# dtype: float64
# -9
# Balanced Accuracy       0.499977
# MCC                    -0.000216
# Accuracy                0.967365
# F1-Score                0.015601
# Precision               0.019476
# Recall                  0.013043
# True Negatives       2216.600000
# False Positives        29.400000
# False Negatives        45.400000
# True Positives          0.600000
# dtype: float64
# -12
# Balanced Accuracy       0.495280
# MCC                    -0.013734
# Accuracy                0.970681
# F1-Score                0.000000
# Precision               0.000000
# Recall                  0.000000
# True Negatives       2224.800000
# False Positives        21.200000
# False Negatives        46.000000
# True Positives          0.000000
# dtype: float64
# 2/6
# -3
# Balanced Accuracy       0.517843
# MCC                     0.053835
# Accuracy                0.973168
# F1-Score                0.059981
# Precision               0.102310
# Recall                  0.043478
# True Negatives       2228.500000
# False Positives        17.500000
# False Negatives        44.000000
# True Positives          2.000000
# dtype: float64
# -6
# Balanced Accuracy       0.503223
# MCC                     0.008068
# Accuracy                0.971640
# F1-Score                0.019845
# Precision               0.029860
# Recall                  0.015217
# True Negatives       2226.300000
# False Positives        19.700000
# False Negatives        45.300000
# True Positives          0.700000
# dtype: float64
# -9
# Balanced Accuracy       0.495833
# MCC                    -0.009664
# Accuracy                0.969677
# F1-Score                0.003571
# Precision               0.010000
# Recall                  0.002174
# True Negatives       2222.400000
# False Positives        23.600000
# False Negatives        45.900000
# True Positives          0.100000
# dtype: float64
# -12
# Balanced Accuracy       0.495736
# MCC                    -0.009960
# Accuracy                0.965314
# F1-Score                0.006983
# Precision               0.008237
# Recall                  0.006522
# True Negatives       2212.200000
# False Positives        33.800000
# False Negatives        45.700000
# True Positives          0.300000
# dtype: float64
# 3/6
# -3
# Balanced Accuracy       0.554867
# MCC                     0.159011
# Accuracy                0.974782
# F1-Score                0.158365
# Precision               0.250631
# Recall                  0.117391
# True Negatives       2228.800000
# False Positives        17.200000
# False Negatives        40.600000
# True Positives          5.400000
# dtype: float64
# -6
# Balanced Accuracy       0.509726
# MCC                     0.032276
# Accuracy                0.973953
# F1-Score                0.035997
# Precision               0.085094
# Recall                  0.026087
# True Negatives       2231.100000
# False Positives        14.900000
# False Negatives        44.800000
# True Positives          1.200000
# dtype: float64
# -9
# Balanced Accuracy       0.510546
# MCC                     0.028997
# Accuracy                0.973473
# F1-Score                0.037724
# Precision               0.059252
# Recall                  0.028261
# True Negatives       2229.900000
# False Positives        16.100000
# False Negatives        44.700000
# True Positives          1.300000
# dtype: float64
# -12
# Balanced Accuracy       0.496457
# MCC                    -0.010863
# Accuracy                0.970899
# F1-Score                0.002632
# Precision               0.003333
# Recall                  0.002174
# True Negatives       2225.200000
# False Positives        20.800000
# False Negatives        45.900000
# True Positives          0.100000
# dtype: float64
# 4/6
# -3
# Balanced Accuracy       0.549940
# MCC                     0.136839
# Accuracy                0.973473
# F1-Score                0.140655
# Precision               0.209047
# Recall                  0.108696
# True Negatives       2226.200000
# False Positives        19.800000
# False Negatives        41.000000
# True Positives          5.000000
# dtype: float64
# -6
# Balanced Accuracy       0.550252
# MCC                     0.143369
# Accuracy                0.974084
# F1-Score                0.144808
# Precision               0.225461
# Recall                  0.108696
# True Negatives       2227.600000
# False Positives        18.400000
# False Negatives        41.000000
# True Positives          5.000000
# dtype: float64
# -9
# Balanced Accuracy       0.515847
# MCC                     0.049281
# Accuracy                0.973429
# F1-Score                0.054715
# Precision               0.097763
# Recall                  0.039130
# True Negatives       2229.300000
# False Positives        16.700000
# False Negatives        44.200000
# True Positives          1.800000
# dtype: float64
# -12
# Balanced Accuracy       0.520481
# MCC                     0.050579
# Accuracy                0.972077
# F1-Score                0.061627
# Precision               0.081508
# Recall                  0.050000
# True Negatives       2225.700000
# False Positives        20.300000
# False Negatives        43.700000
# True Positives          2.300000
# dtype: float64
# 5/6
# -3
# Balanced Accuracy       0.547302
# MCC                     0.140407
# Accuracy                0.974564
# F1-Score                0.138161
# Precision               0.233079
# Recall                  0.102174
# True Negatives       2229.000000
# False Positives        17.000000
# False Negatives        41.300000
# True Positives          4.700000
# dtype: float64
# -6
# Balanced Accuracy       0.569042
# MCC                     0.194657
# Accuracy                0.975436
# F1-Score                0.191829
# Precision               0.297984
# Recall                  0.145652
# True Negatives       2229.000000
# False Positives        17.000000
# False Negatives        39.300000
# True Positives          6.700000
# dtype: float64
# -9
# Balanced Accuracy       0.551739
# MCC                     0.153984
# Accuracy                0.974913
# F1-Score                0.151235
# Precision               0.251752
# Recall                  0.110870
# True Negatives       2229.400000
# False Positives        16.600000
# False Negatives        40.900000
# True Positives          5.100000
# dtype: float64
# -12
# Balanced Accuracy       0.549632
# MCC                     0.143418
# Accuracy                0.974956
# F1-Score                0.143682
# Precision               0.227688
# Recall                  0.106522
# True Negatives       2229.700000
# False Positives        16.300000
# False Negatives        41.100000
# True Positives          4.900000
# dtype: float64
# 6/6
# -3
# Balanced Accuracy       0.556395
# MCC                     0.154076
# Accuracy                0.973604
# F1-Score                0.157559
# Precision               0.230959
# Recall                  0.121739
# True Negatives       2225.900000
# False Positives        20.100000
# False Negatives        40.400000
# True Positives          5.600000
# dtype: float64
# -6
# Balanced Accuracy       0.554577
# MCC                     0.150933
# Accuracy                0.974215
# F1-Score                0.153530
# Precision               0.229131
# Recall                  0.117391
# True Negatives       2227.500000
# False Positives        18.500000
# False Negatives        40.600000
# True Positives          5.400000
# dtype: float64
# -9
# Balanced Accuracy       0.549651
# MCC                     0.133029
# Accuracy                0.972906
# F1-Score                0.138745
# Precision               0.198814
# Recall                  0.108696
# True Negatives       2224.900000
# False Positives        21.100000
# False Negatives        41.000000
# True Positives          5.000000
# dtype: float64
# -12
# Balanced Accuracy       0.565580
# MCC                     0.181627
# Accuracy                0.974913
# F1-Score                0.180747
# Precision               0.275403
# Recall                  0.139130
# True Negatives       2228.100000
# False Positives        17.900000
# False Negatives        39.600000
# True Positives          6.400000
# dtype: float64
# Aggregated 1+2
# 1/5
# -3
# Balanced Accuracy       0.497989
# MCC                    -0.006594
# Accuracy                0.971815
# F1-Score                0.005802
# Precision               0.008762
# Recall                  0.004348
# True Negatives       2227.200000
# False Positives        18.800000
# False Negatives        45.800000
# True Positives          0.200000
# dtype: float64
# -6
# Balanced Accuracy       0.498070
# MCC                    -0.003896
# Accuracy                0.967801
# F1-Score                0.011224
# Precision               0.016062
# Recall                  0.008696
# True Negatives       2217.800000
# False Positives        28.200000
# False Negatives        45.600000
# True Positives          0.400000
# dtype: float64
# -9
# Balanced Accuracy       0.502548
# MCC                     0.005508
# Accuracy                0.966143
# F1-Score                0.022094
# Precision               0.025959
# Recall                  0.019565
# True Negatives       2213.500000
# False Positives        32.500000
# False Negatives        45.100000
# True Positives          0.900000
# dtype: float64
# -12
# Balanced Accuracy       0.491897
# MCC                    -0.018094
# Accuracy                0.964049
# F1-Score                0.000000
# Precision               0.000000
# Recall                  0.000000
# True Negatives       2209.600000
# False Positives        36.400000
# False Negatives        46.000000
# True Positives          0.000000
# dtype: float64
# 2/5
# -3
# Balanced Accuracy       0.512390
# MCC                     0.047641
# Accuracy                0.975000
# F1-Score                0.047512
# Precision               0.112016
# Recall                  0.030435
# True Negatives       2233.300000
# False Positives        12.700000
# False Negatives        44.600000
# True Positives          1.400000
# dtype: float64
# -6
# Balanced Accuracy       0.499009
# MCC                    -0.003781
# Accuracy                0.971728
# F1-Score                0.008704
# Precision               0.013167
# Recall                  0.006522
# True Negatives       2226.900000
# False Positives        19.100000
# False Negatives        45.700000
# True Positives          0.300000
# dtype: float64
# -9
# Balanced Accuracy       0.499851
# MCC                    -0.000992
# Accuracy                0.971291
# F1-Score                0.011606
# Precision               0.017558
# Recall                  0.008696
# True Negatives       2225.800000
# False Positives        20.200000
# False Negatives        45.600000
# True Positives          0.400000
# dtype: float64
# -12
# Balanced Accuracy       0.500823
# MCC                     0.001648
# Accuracy                0.969023
# F1-Score                0.016173
# Precision               0.021454
# Recall                  0.013043
# True Negatives       2220.400000
# False Positives        25.600000
# False Negatives        45.400000
# True Positives          0.600000
# dtype: float64
# 3/5
# -3
# Balanced Accuracy       0.660298
# MCC                     0.355170
# Accuracy                0.976920
# F1-Score                0.364027
# Precision               0.408554
# Recall                  0.330435
# True Negatives       2223.900000
# False Positives        22.100000
# False Negatives        30.800000
# True Positives         15.200000
# dtype: float64
# -6
# Balanced Accuracy       0.535702
# MCC                     0.111830
# Accuracy                0.974782
# F1-Score                0.110897
# Precision               0.195284
# Recall                  0.078261
# True Negatives       2230.600000
# False Positives        15.400000
# False Negatives        42.400000
# True Positives          3.600000
# dtype: float64
# -9
# Balanced Accuracy       0.519950
# MCC                     0.058814
# Accuracy                0.973124
# F1-Score                0.065335
# Precision               0.107293
# Recall                  0.047826
# True Negatives       2228.200000
# False Positives        17.800000
# False Negatives        43.800000
# True Positives          2.200000
# dtype: float64
# -12
# Balanced Accuracy       0.505263
# MCC                     0.015513
# Accuracy                0.971466
# F1-Score                0.026479
# Precision               0.042275
# Recall                  0.019565
# True Negatives       2225.700000
# False Positives        20.300000
# False Negatives        45.100000
# True Positives          0.900000
# dtype: float64
# 4/5
# -3
# Balanced Accuracy       0.658636
# MCC                     0.366477
# Accuracy                0.977836
# F1-Score                0.372019
# Precision               0.440005
# Recall                  0.326087
# True Negatives       2226.200000
# False Positives        19.800000
# False Negatives        31.000000
# True Positives         15.000000
# dtype: float64
# -6
# Balanced Accuracy       0.648163
# MCC                     0.329512
# Accuracy                0.976091
# F1-Score                0.338652
# Precision               0.382197
# Recall                  0.306522
# True Negatives       2223.100000
# False Positives        22.900000
# False Negatives        31.900000
# True Positives         14.100000
# dtype: float64
# -9
# Balanced Accuracy       0.660472
# MCC                     0.338760
# Accuracy                0.975175
# F1-Score                0.349690
# Precision               0.373238
# Recall                  0.332609
# True Negatives       2219.800000
# False Positives        26.200000
# False Negatives        30.700000
# True Positives         15.300000
# dtype: float64
# -12
# Balanced Accuracy       0.530468
# MCC                     0.097382
# Accuracy                0.974956
# F1-Score                0.095373
# Precision               0.179687
# Recall                  0.067391
# True Negatives       2231.500000
# False Positives        14.500000
# False Negatives        42.900000
# True Positives          3.100000
# dtype: float64
# 5/5
# -3
# Balanced Accuracy       0.641111
# MCC                     0.331428
# Accuracy                0.976876
# F1-Score                0.336794
# Precision               0.406874
# Recall                  0.291304
# True Negatives       2225.600000
# False Positives        20.400000
# False Negatives        32.600000
# True Positives         13.400000
# dtype: float64
# -6
# Balanced Accuracy       0.652555
# MCC                     0.340815
# Accuracy                0.976353
# F1-Score                0.348992
# Precision               0.397537
# Recall                  0.315217
# True Negatives       2223.300000
# False Positives        22.700000
# False Negatives        31.500000
# True Positives         14.500000
# dtype: float64
# -9
# Balanced Accuracy       0.651758
# MCC                     0.341842
# Accuracy                0.976876
# F1-Score                0.347159
# Precision               0.407252
# Recall                  0.313043
# True Negatives       2224.600000
# False Positives        21.400000
# False Negatives        31.600000
# True Positives         14.400000
# dtype: float64
# -12
# Balanced Accuracy       0.650912
# MCC                     0.323661
# Accuracy                0.975218
# F1-Score                0.334619
# Precision               0.362427
# Recall                  0.313043
# True Negatives       2220.800000
# False Positives        25.200000
# False Negatives        31.600000
# True Positives         14.400000
# dtype: float64
# Aggregated 1+2+4
# 1/6
# -3
# Balanced Accuracy       0.504659
# MCC                     0.008471
# Accuracy                0.968194
# F1-Score                0.023558
# Precision               0.026491
# Recall                  0.021739
# True Negatives       2218.100000
# False Positives        27.900000
# False Negatives        45.000000
# True Positives          1.000000
# dtype: float64
# -6
# Balanced Accuracy       0.501754
# MCC                     0.003732
# Accuracy                0.968761
# F1-Score                0.018357
# Precision               0.023751
# Recall                  0.015217
# True Negatives       2219.700000
# False Positives        26.300000
# False Negatives        45.300000
# True Positives          0.700000
# dtype: float64
# -9
# Balanced Accuracy       0.503634
# MCC                     0.010478
# Accuracy                0.966187
# F1-Score                0.026108
# Precision               0.035050
# Recall                  0.021739
# True Negatives       2213.500000
# False Positives        32.500000
# False Negatives        45.000000
# True Positives          1.000000
# dtype: float64
# -12
# Balanced Accuracy       0.495614
# MCC                    -0.013192
# Accuracy                0.971335
# F1-Score                0.000000
# Precision               0.000000
# Recall                  0.000000
# True Negatives       2226.300000
# False Positives        19.700000
# False Negatives        46.000000
# True Positives          0.000000
# dtype: float64
# 2/6
# -3
# Balanced Accuracy       0.544019
# MCC                     0.129812
# Accuracy                0.974389
# F1-Score                0.130250
# Precision               0.212754
# Recall                  0.095652
# True Negatives       2228.900000
# False Positives        17.100000
# False Negatives        41.600000
# True Positives          4.400000
# dtype: float64
# -6
# Balanced Accuracy       0.498100
# MCC                    -0.006485
# Accuracy                0.972033
# F1-Score                0.005770
# Precision               0.008704
# Recall                  0.004348
# True Negatives       2227.700000
# False Positives        18.300000
# False Negatives        45.800000
# True Positives          0.200000
# dtype: float64
# -9
# Balanced Accuracy       0.503968
# MCC                     0.009782
# Accuracy                0.966841
# F1-Score                0.025317
# Precision               0.032390
# Recall                  0.021739
# True Negatives       2215.000000
# False Positives        31.000000
# False Negatives        45.000000
# True Positives          1.000000
# dtype: float64
# -12
# Balanced Accuracy       0.502240
# MCC                     0.005294
# Accuracy                0.967627
# F1-Score                0.020731
# Precision               0.026039
# Recall                  0.017391
# True Negatives       2217.000000
# False Positives        29.000000
# False Negatives        45.200000
# True Positives          0.800000
# dtype: float64
# 3/6
# -3
# Balanced Accuracy       0.634500
# MCC                     0.316041
# Accuracy                0.976440
# F1-Score                0.321655
# Precision               0.389312
# Recall                  0.278261
# True Negatives       2225.200000
# False Positives        20.800000
# False Negatives        33.200000
# True Positives         12.800000
# dtype: float64
# -6
# Balanced Accuracy       0.580486
# MCC                     0.213026
# Accuracy                0.974913
# F1-Score                0.212342
# Precision               0.308156
# Recall                  0.169565
# True Negatives       2226.700000
# False Positives        19.300000
# False Negatives        38.200000
# True Positives          7.800000
# dtype: float64
# -9
# Balanced Accuracy       0.507397
# MCC                     0.028353
# Accuracy                0.973560
# F1-Score                0.033278
# Precision               0.074361
# Recall                  0.021739
# True Negatives       2230.400000
# False Positives        15.600000
# False Negatives        45.000000
# True Positives          1.000000
# dtype: float64
# -12
# Balanced Accuracy       0.510917
# MCC                     0.031546
# Accuracy                0.970026
# F1-Score                0.042821
# Precision               0.065981
# Recall                  0.032609
# True Negatives       2221.800000
# False Positives        24.200000
# False Negatives        44.500000
# True Positives          1.500000
# dtype: float64
# 4/6
# -3
# Balanced Accuracy       0.619768
# MCC                     0.273795
# Accuracy                0.974695
# F1-Score                0.282716
# Precision               0.330231
# Recall                  0.250000
# True Negatives       2222.500000
# False Positives        23.500000
# False Negatives        34.500000
# True Positives         11.500000
# dtype: float64
# -6
# Balanced Accuracy       0.640688
# MCC                     0.319874
# Accuracy                0.976047
# F1-Score                0.327912
# Precision               0.380215
# Recall                  0.291304
# True Negatives       2223.700000
# False Positives        22.300000
# False Negatives        32.600000
# True Positives         13.400000
# dtype: float64
# -9
# Balanced Accuracy       0.630924
# MCC                     0.285491
# Accuracy                0.973604
# F1-Score                0.294499
# Precision               0.331977
# Recall                  0.273913
# True Negatives       2218.900000
# False Positives        27.100000
# False Negatives        33.400000
# True Positives         12.600000
# dtype: float64
# -12
# Balanced Accuracy       0.548590
# MCC                     0.141644
# Accuracy                0.975000
# F1-Score                0.141356
# Precision               0.227205
# Recall                  0.104348
# True Negatives       2229.900000
# False Positives        16.100000
# False Negatives        41.200000
# True Positives          4.800000
# dtype: float64
# 5/6
# -3
# Balanced Accuracy       0.645789
# MCC                     0.321408
# Accuracy                0.975611
# F1-Score                0.331360
# Precision               0.369798
# Recall                  0.302174
# True Negatives       2222.200000
# False Positives        23.800000
# False Negatives        32.100000
# True Positives         13.900000
# dtype: float64
# -6
# Balanced Accuracy       0.652110
# MCC                     0.332322
# Accuracy                0.975480
# F1-Score                0.341716
# Precision               0.379949
# Recall                  0.315217
# True Negatives       2221.300000
# False Positives        24.700000
# False Negatives        31.500000
# True Positives         14.500000
# dtype: float64
# -9
# Balanced Accuracy       0.643080
# MCC                     0.311034
# Accuracy                0.974476
# F1-Score                0.321167
# Precision               0.355317
# Recall                  0.297826
# True Negatives       2219.800000
# False Positives        26.200000
# False Negatives        32.300000
# True Positives         13.700000
# dtype: float64
# -12
# Balanced Accuracy       0.622143
# MCC                     0.284872
# Accuracy                0.975175
# F1-Score                0.290854
# Precision               0.352668
# Recall                  0.254348
# True Negatives       2223.400000
# False Positives        22.600000
# False Negatives        34.300000
# True Positives         11.700000
# dtype: float64
# 6/6
# -3
# Balanced Accuracy       0.634255
# MCC                     0.306241
# Accuracy                0.975960
# F1-Score                0.314466
# Precision               0.365757
# Recall                  0.278261
# True Negatives       2224.100000
# False Positives        21.900000
# False Negatives        33.200000
# True Positives         12.800000
# dtype: float64
# -6
# Balanced Accuracy       0.635921
# MCC                     0.323770
# Accuracy                0.977138
# F1-Score                0.328909
# Precision               0.402030
# Recall                  0.280435
# True Negatives       2226.700000
# False Positives        19.300000
# False Negatives        33.100000
# True Positives         12.900000
# dtype: float64
# -9
# Balanced Accuracy       0.626157
# MCC                     0.286272
# Accuracy                0.974695
# F1-Score                0.294544
# Precision               0.343488
# Recall                  0.263043
# True Negatives       2221.900000
# False Positives        24.100000
# False Negatives        33.900000
# True Positives         12.100000
# dtype: float64
# -12
# Balanced Accuracy       0.636162
# MCC                     0.306740
# Accuracy                0.975524
# F1-Score                0.314501
# Precision               0.364439
# Recall                  0.282609
# True Negatives       2222.900000
# False Positives        23.100000
# False Negatives        33.000000
# True Positives         13.000000
# dtype: float64
# Aggregated 1+2+3+4
# 1/6
# -3
# Balanced Accuracy       0.507233
# MCC                     0.015563
# Accuracy                0.969066
# F1-Score                0.029913
# Precision               0.036069
# Recall                  0.026087
# True Negatives       2219.900000
# False Positives        26.100000
# False Negatives        44.800000
# True Positives          1.200000
# dtype: float64
# -6
# Balanced Accuracy       0.497005
# MCC                    -0.007843
# Accuracy                0.967801
# F1-Score                0.007591
# Precision               0.009362
# Recall                  0.006522
# True Negatives       2217.900000
# False Positives        28.100000
# False Negatives        45.700000
# True Positives          0.300000
# dtype: float64
# -9
# Balanced Accuracy       0.503345
# MCC                     0.007751
# Accuracy                0.965620
# F1-Score                0.024459
# Precision               0.028846
# Recall                  0.021739
# True Negatives       2212.200000
# False Positives        33.800000
# False Negatives        45.000000
# True Positives          1.000000
# dtype: float64
# -12
# Balanced Accuracy       0.493967
# MCC                    -0.015632
# Accuracy                0.968106
# F1-Score                0.000000
# Precision               0.000000
# Recall                  0.000000
# True Negatives       2218.900000
# False Positives        27.100000
# False Negatives        46.000000
# True Positives          0.000000
# dtype: float64
# 2/6
# -3
# Balanced Accuracy       0.502185
# MCC                     0.006404
# Accuracy                0.973778
# F1-Score                0.015542
# Precision               0.028923
# Recall                  0.010870
# True Negatives       2231.400000
# False Positives        14.600000
# False Negatives        45.500000
# True Positives          0.500000
# dtype: float64
# -6
# Balanced Accuracy       0.500318
# MCC                     0.000152
# Accuracy                0.972208
# F1-Score                0.011707
# Precision               0.019102
# Recall                  0.008696
# True Negatives       2227.900000
# False Positives        18.100000
# False Negatives        45.600000
# True Positives          0.400000
# dtype: float64
# -9
# Balanced Accuracy       0.498623
# MCC                    -0.003899
# Accuracy                0.966798
# F1-Score                0.012249
# Precision               0.014627
# Recall                  0.010870
# True Negatives       2215.400000
# False Positives        30.600000
# False Negatives        45.500000
# True Positives          0.500000
# dtype: float64
# -12
# Balanced Accuracy       0.503564
# MCC                     0.006816
# Accuracy                0.963962
# F1-Score                0.024897
# Precision               0.026276
# Recall                  0.023913
# True Negatives       2208.300000
# False Positives        37.700000
# False Negatives        44.900000
# True Positives          1.100000
# dtype: float64
# 3/6
# -3
# Balanced Accuracy       0.547659
# MCC                     0.146818
# Accuracy                0.975262
# F1-Score                0.141454
# Precision               0.251337
# Recall                  0.102174
# True Negatives       2230.600000
# False Positives        15.400000
# False Negatives        41.300000
# True Positives          4.700000
# dtype: float64
# -6
# Balanced Accuracy       0.543667
# MCC                     0.140329
# Accuracy                0.975785
# F1-Score                0.132707
# Precision               0.250652
# Recall                  0.093478
# True Negatives       2232.200000
# False Positives        13.800000
# False Negatives        41.700000
# True Positives          4.300000
# dtype: float64
# -9
# Balanced Accuracy       0.503557
# MCC                     0.012167
# Accuracy                0.972295
# F1-Score                0.021826
# Precision               0.040799
# Recall                  0.015217
# True Negatives       2227.800000
# False Positives        18.200000
# False Negatives        45.300000
# True Positives          0.700000
# dtype: float64
# -12
# Balanced Accuracy       0.505798
# MCC                     0.017840
# Accuracy                0.972513
# F1-Score                0.027192
# Precision               0.048049
# Recall                  0.019565
# True Negatives       2228.100000
# False Positives        17.900000
# False Negatives        45.100000
# True Positives          0.900000
# dtype: float64
# 4/6
# -3
# Balanced Accuracy       0.630215
# MCC                     0.289288
# Accuracy                0.974302
# F1-Score                0.299337
# Precision               0.338373
# Recall                  0.271739
# True Negatives       2220.600000
# False Positives        25.400000
# False Negatives        33.500000
# True Positives         12.500000
# dtype: float64
# -6
# Balanced Accuracy       0.639182
# MCC                     0.327352
# Accuracy                0.977269
# F1-Score                0.330492
# Precision               0.406884
# Recall                  0.286957
# True Negatives       2226.700000
# False Positives        19.300000
# False Negatives        32.800000
# True Positives         13.200000
# dtype: float64
# -9
# Balanced Accuracy       0.558795
# MCC                     0.174690
# Accuracy                0.976222
# F1-Score                0.168667
# Precision               0.285244
# Recall                  0.123913
# True Negatives       2231.800000
# False Positives        14.200000
# False Negatives        40.300000
# True Positives          5.700000
# dtype: float64
# -12
# Balanced Accuracy       0.499035
# MCC                    -0.001886
# Accuracy                0.973866
# F1-Score                0.007080
# Precision               0.019091
# Recall                  0.004348
# True Negatives       2231.900000
# False Positives        14.100000
# False Negatives        45.800000
# True Positives          0.200000
# dtype: float64
# 5/6
# -3
# Balanced Accuracy       0.641997
# MCC                     0.325456
# Accuracy                0.976527
# F1-Score                0.333235
# Precision               0.388712
# Recall                  0.293478
# True Negatives       2224.700000
# False Positives        21.300000
# False Negatives        32.500000
# True Positives         13.500000
# dtype: float64
# -6
# Balanced Accuracy       0.622874
# MCC                     0.278153
# Accuracy                0.974520
# F1-Score                0.287565
# Precision               0.331991
# Recall                  0.256522
# True Negatives       2221.800000
# False Positives        24.200000
# False Negatives        34.200000
# True Positives         11.800000
# dtype: float64
# -9
# Balanced Accuracy       0.637650
# MCC                     0.318541
# Accuracy                0.976353
# F1-Score                0.325186
# Precision               0.386080
# Recall                  0.284783
# True Negatives       2224.700000
# False Positives        21.300000
# False Negatives        32.900000
# True Positives         13.100000
# dtype: float64
# -12
# Balanced Accuracy       0.629529
# MCC                     0.292593
# Accuracy                0.975044
# F1-Score                0.301761
# Precision               0.347291
# Recall                  0.269565
# True Negatives       2222.400000
# False Positives        23.600000
# False Negatives        33.600000
# True Positives         12.400000
# dtype: float64
# 6/6
# -3
# Balanced Accuracy       0.631992
# MCC                     0.304971
# Accuracy                0.975698
# F1-Score                0.311689
# Precision               0.370892
# Recall                  0.273913
# True Negatives       2223.700000
# False Positives        22.300000
# False Negatives        33.400000
# True Positives         12.600000
# dtype: float64
# -6
# Balanced Accuracy       0.648096
# MCC                     0.330514
# Accuracy                0.975960
# F1-Score                0.339029
# Precision               0.385687
# Recall                  0.306522
# True Negatives       2222.800000
# False Positives        23.200000
# False Negatives        31.900000
# True Positives         14.100000
# dtype: float64
# -9
# Balanced Accuracy       0.627426
# MCC                     0.311935
# Accuracy                0.977182
# F1-Score                0.315875
# Precision               0.397791
# Recall                  0.263043
# True Negatives       2227.600000
# False Positives        18.400000
# False Negatives        33.900000
# True Positives         12.100000
# dtype: float64
# -12
# Balanced Accuracy       0.615380
# MCC                     0.283019
# Accuracy                0.976527
# F1-Score                0.287397
# Precision               0.364198
# Recall                  0.239130
# True Negatives       2227.200000
# False Positives        18.800000
# False Negatives        35.000000
# True Positives         11.000000
# dtype: float64
# Standard 2
# 1/5
# -3
# Balanced Accuracy       0.510818
# MCC                     0.020910
# Accuracy                0.933353
# F1-Score                0.055184
# Precision               0.053615
# Recall                  0.057391
# True Negatives       3144.400000
# False Positives       116.600000
# False Negatives       108.400000
# True Positives          6.600000
# dtype: float64
# -6
# Balanced Accuracy       0.502532
# MCC                     0.005434
# Accuracy                0.931931
# F1-Score                0.040531
# Precision               0.039689
# Recall                  0.041739
# True Negatives       3141.400000
# False Positives       119.600000
# False Negatives       110.200000
# True Positives          4.800000
# dtype: float64
# -9
# Balanced Accuracy       0.502028
# MCC                     0.003553
# Accuracy                0.937441
# F1-Score                0.035663
# Precision               0.036947
# Recall                  0.034783
# True Negatives       3160.800000
# False Positives       100.200000
# False Negatives       111.000000
# True Positives          4.000000
# dtype: float64
# -12
# Balanced Accuracy       0.522940
# MCC                     0.053575
# Accuracy                0.946238
# F1-Score                0.079427
# Precision               0.095413
# Recall                  0.068696
# True Negatives       3186.600000
# False Positives        74.400000
# False Negatives       107.100000
# True Positives          7.900000
# dtype: float64
# 2/5
# -3
# Balanced Accuracy       0.517705
# MCC                     0.036801
# Accuracy                0.939366
# F1-Score                0.067961
# Precision               0.071152
# Recall                  0.065217
# True Negatives       3163.800000
# False Positives        97.200000
# False Negatives       107.500000
# True Positives          7.500000
# dtype: float64
# -6
# Balanced Accuracy       0.512051
# MCC                     0.022357
# Accuracy                0.932494
# F1-Score                0.057131
# Precision               0.053990
# Recall                  0.060870
# True Negatives       3141.100000
# False Positives       119.900000
# False Negatives       108.000000
# True Positives          7.000000
# dtype: float64
# -9
# Balanced Accuracy       0.514346
# MCC                     0.028105
# Accuracy                0.935308
# F1-Score                0.061441
# Precision               0.060685
# Recall                  0.062609
# True Negatives       3150.400000
# False Positives       110.600000
# False Negatives       107.800000
# True Positives          7.200000
# dtype: float64
# -12
# Balanced Accuracy       0.497558
# MCC                    -0.004753
# Accuracy                0.934479
# F1-Score                0.029037
# Precision               0.029577
# Recall                  0.028696
# True Negatives       3151.500000
# False Positives       109.500000
# False Negatives       111.700000
# True Positives          3.300000
# dtype: float64
# 3/5
# -3
# Balanced Accuracy       0.534688
# MCC                     0.069278
# Accuracy                0.938951
# F1-Score                0.100674
# Precision               0.101069
# Recall                  0.100870
# True Negatives       3158.300000
# False Positives       102.700000
# False Negatives       103.400000
# True Positives         11.600000
# dtype: float64
# -6
# Balanced Accuracy       0.521900
# MCC                     0.045784
# Accuracy                0.939366
# F1-Score                0.076935
# Precision               0.080509
# Recall                  0.073913
# True Negatives       3162.800000
# False Positives        98.200000
# False Negatives       106.500000
# True Positives          8.500000
# dtype: float64
# -9
# Balanced Accuracy       0.514044
# MCC                     0.028040
# Accuracy                0.936345
# F1-Score                0.060899
# Precision               0.061122
# Recall                  0.060870
# True Negatives       3154.100000
# False Positives       106.900000
# False Negatives       108.000000
# True Positives          7.000000
# dtype: float64
# -12
# Balanced Accuracy       0.513948
# MCC                     0.026585
# Accuracy                0.934538
# F1-Score                0.060217
# Precision               0.058616
# Recall                  0.062609
# True Negatives       3147.800000
# False Positives       113.200000
# False Negatives       107.800000
# True Positives          7.200000
# dtype: float64
# 4/5
# -3
# Balanced Accuracy       0.516794
# MCC                     0.036729
# Accuracy                0.940847
# F1-Score                0.066806
# Precision               0.073148
# Recall                  0.061739
# True Negatives       3169.200000
# False Positives        91.800000
# False Negatives       107.900000
# True Positives          7.100000
# dtype: float64
# -6
# Balanced Accuracy       0.513740
# MCC                     0.030474
# Accuracy                0.942239
# F1-Score                0.059437
# Precision               0.067133
# Recall                  0.053913
# True Negatives       3174.800000
# False Positives        86.200000
# False Negatives       108.800000
# True Positives          6.200000
# dtype: float64
# -9
# Balanced Accuracy       0.529337
# MCC                     0.059863
# Accuracy                0.939959
# F1-Score                0.090605
# Precision               0.093361
# Recall                  0.088696
# True Negatives       3163.100000
# False Positives        97.900000
# False Negatives       104.800000
# True Positives         10.200000
# dtype: float64
# -12
# Balanced Accuracy       0.520310
# MCC                     0.041339
# Accuracy                0.937915
# F1-Score                0.073399
# Precision               0.074784
# Recall                  0.072174
# True Negatives       3158.100000
# False Positives       102.900000
# False Negatives       106.700000
# True Positives          8.300000
# dtype: float64
# 5/5
# -3
# Balanced Accuracy       0.515515
# MCC                     0.034068
# Accuracy                0.941617
# F1-Score                0.063420
# Precision               0.070629
# Recall                  0.058261
# True Negatives       3172.200000
# False Positives        88.800000
# False Negatives       108.300000
# True Positives          6.700000
# dtype: float64
# -6
# Balanced Accuracy       0.526692
# MCC                     0.056007
# Accuracy                0.940521
# F1-Score                0.086519
# Precision               0.091086
# Recall                  0.082609
# True Negatives       3165.700000
# False Positives        95.300000
# False Negatives       105.500000
# True Positives          9.500000
# dtype: float64
# -9
# Balanced Accuracy       0.521740
# MCC                     0.048231
# Accuracy                0.942299
# F1-Score                0.077102
# Precision               0.086446
# Recall                  0.070435
# True Negatives       3173.100000
# False Positives        87.900000
# False Negatives       106.900000
# True Positives          8.100000
# dtype: float64
# -12
# Balanced Accuracy       0.537372
# MCC                     0.077811
# Accuracy                0.941706
# F1-Score                0.107567
# Precision               0.112799
# Recall                  0.103478
# True Negatives       3167.300000
# False Positives        93.700000
# False Negatives       103.100000
# True Positives         11.900000
# dtype: float64

# %%
for key in set_dict.keys():
    bigg_df = pd.DataFrame()
    for i in set_dict[key]['PCA n Features']['Runs']['All runs'].keys():
        
        small_df = pd.DataFrame()
        for n_pca_reduction in set_dict[key]['PCA n Features']['Runs']['All runs'][i]:   
            temp_df =set_dict[key]['PCA n Features']['Runs']['All runs'][i][n_pca_reduction]
            temp_df.loc[:,'No. Features'] = i
            temp_df.loc[:,'PCA reduction'] = n_pca_reduction
            
            small_df = pd.concat([small_df,temp_df]).reset_index(drop=True)
        
        bigg_df =pd.concat([bigg_df,small_df]).reset_index(drop=True)        
    set_dict[key]['PCA n Features']['PCA n Features'] = bigg_df
#     plt.tight_layout();
    ax= plot_boxchart(bigg_df,title=key,x='No. Features',xlabel='No. Selected Features',hue='PCA reduction');
